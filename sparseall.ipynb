# %%
import pandas as pd
pd.set_option('display.max_columns', None)
data=pd.read_csv('./vdjdb.txt',sep='\t', header=0)

data
# Out:
#        complex.id gene                  cdr3       v.segm      j.segm  \
# 0               1  TRA         CIVRAPGRADMRF  TRAV26-1*01   TRAJ43*01
# 1               1  TRB  CASSYLPGQGDHYSNQPQHF    TRBV13*01  TRBJ1-5*01
# 2               0  TRB   CASSFEAGQGFFSNQPQHF    TRBV13*01  TRBJ1-5*01
# 3               2  TRA        CAVPSGAGSYQLTF    TRAV20*01   TRAJ28*01
# 4               2  TRB   CASSFEPGQGFYSNQPQHF    TRBV13*01  TRBJ1-5*01
# ...           ...  ...                   ...          ...         ...
# 92766       30592  TRB       CASSPGQGGDNEQFF   TRBV7-3*01  TRBJ2-1*01
# 92767       30593  TRA          CAPQGATNKLIF  TRAV12-2*01   TRAJ32*01
# 92768       30593  TRB       CASSLGAGGQETQYF   TRBV5-1*01  TRBJ2-5*01
# 92769       30594  TRA        CLVGGSGGYNKLIF     TRAV4*01    TRAJ4*01
# 92770       30594  TRB         CASSSTAQETQYF  TRBV11-2*01  TRBJ2-5*01
#
#            species           mhc.a           mhc.b mhc.class antigen.epitope  \
# 0      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# 1      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# 2      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# 3      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# 4      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# ...            ...             ...             ...       ...             ...
# 92766  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII   PQQPFPQPEQPFP
# 92767  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII   PQQPFPQPEQPFP
# 92768  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII   PQQPFPQPEQPFP
# 92769  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII   PQQPFPQPEQPFP
# 92770  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII   PQQPFPQPEQPFP
#
#       antigen.gene antigen.species   reference.id  \
# 0              Nef           HIV-1  PMID:15596521
# 1              Nef           HIV-1  PMID:15596521
# 2              Nef           HIV-1  PMID:15596521
# 3              Nef           HIV-1  PMID:15596521
# 4              Nef           HIV-1  PMID:15596521
# ...            ...             ...            ...
# 92766       Gluten           Wheat  PMID:33927715
# 92767       Gluten           Wheat  PMID:33927715
# 92768       Gluten           Wheat  PMID:33927715
# 92769       Gluten           Wheat  PMID:33927715
# 92770       Gluten           Wheat  PMID:33927715
#
#                                                   method  \
# 0      {"frequency": "", "identification": "tetramer-...
# 1      {"frequency": "", "identification": "tetramer-...
# 2      {"frequency": "", "identification": "tetramer-...
# 3      {"frequency": "", "identification": "tetramer-...
# 4      {"frequency": "", "identification": "tetramer-...
# ...                                                  ...
# 92766  {"frequency": "", "identification": "tetramer-...
# 92767  {"frequency": "", "identification": "tetramer-...
# 92768  {"frequency": "", "identification": "tetramer-...
# 92769  {"frequency": "", "identification": "tetramer-...
# 92770  {"frequency": "", "identification": "tetramer-...
#
#                                                     meta  \
# 0      {"cell.subset": "CD8+", "clone.id": "", "donor...
# 1      {"cell.subset": "CD8+", "clone.id": "", "donor...
# 2      {"cell.subset": "CD8+", "clone.id": "", "donor...
# 3      {"cell.subset": "CD8+", "clone.id": "", "donor...
# 4      {"cell.subset": "CD8+", "clone.id": "", "donor...
# ...                                                  ...
# 92766  {"cell.subset": "CD4+", "clone.id": "", "donor...
# 92767  {"cell.subset": "CD4+", "clone.id": "", "donor...
# 92768  {"cell.subset": "CD4+", "clone.id": "", "donor...
# 92769  {"cell.subset": "CD4+", "clone.id": "", "donor...
# 92770  {"cell.subset": "CD4+", "clone.id": "", "donor...
#
#                                                  cdr3fix  vdjdb.score  \
# 0      {"cdr3": "CIVRAPGRADMRF", "cdr3_old": "CIVRAPG...            2
# 1      {"cdr3": "CASSYLPGQGDHYSNQPQHF", "cdr3_old": "...            2
# 2      {"cdr3": "CASSFEAGQGFFSNQPQHF", "cdr3_old": "C...            2
# 3      {"cdr3": "CAVPSGAGSYQLTF", "cdr3_old": "CAVPSG...            2
# 4      {"cdr3": "CASSFEPGQGFYSNQPQHF", "cdr3_old": "C...            2
# ...                                                  ...          ...
# 92766  {"cdr3": "CASSPGQGGDNEQFF", "cdr3_old": "CASSP...            0
# 92767  {"cdr3": "CAPQGATNKLIF", "cdr3_old": "CAPQGATN...            2
# 92768  {"cdr3": "CASSLGAGGQETQYF", "cdr3_old": "CASSL...            2
# 92769  {"cdr3": "CLVGGSGGYNKLIF", "cdr3_old": "CLVGGS...            0
# 92770  {"cdr3": "CASSSTAQETQYF", "cdr3_old": "CASSSTA...            0
#
#       web.method web.method.seq web.cdr3fix.nc web.cdr3fix.unmp
# 0           sort         sanger             no               no
# 1           sort         sanger             no               no
# 2           sort         sanger             no               no
# 3           sort         sanger             no               no
# 4           sort         sanger             no               no
# ...          ...            ...            ...              ...
# 92766       sort     singlecell             no               no
# 92767       sort     singlecell             no               no
# 92768       sort     singlecell             no               no
# 92769       sort     singlecell             no               no
# 92770       sort     singlecell             no               no
#
# [92771 rows x 21 columns]

# %%
data.head
# Out:
# <bound method NDFrame.head of        complex.id gene                  cdr3       v.segm      j.segm  \
# 0               1  TRA         CIVRAPGRADMRF  TRAV26-1*01   TRAJ43*01
# 1               1  TRB  CASSYLPGQGDHYSNQPQHF    TRBV13*01  TRBJ1-5*01
# 2               0  TRB   CASSFEAGQGFFSNQPQHF    TRBV13*01  TRBJ1-5*01
# 3               2  TRA        CAVPSGAGSYQLTF    TRAV20*01   TRAJ28*01
# 4               2  TRB   CASSFEPGQGFYSNQPQHF    TRBV13*01  TRBJ1-5*01
# ...           ...  ...                   ...          ...         ...
# 92766       30592  TRB       CASSPGQGGDNEQFF   TRBV7-3*01  TRBJ2-1*01
# 92767       30593  TRA          CAPQGATNKLIF  TRAV12-2*01   TRAJ32*01
# 92768       30593  TRB       CASSLGAGGQETQYF   TRBV5-1*01  TRBJ2-5*01
# 92769       30594  TRA        CLVGGSGGYNKLIF     TRAV4*01    TRAJ4*01
# 92770       30594  TRB         CASSSTAQETQYF  TRBV11-2*01  TRBJ2-5*01
#
#            species           mhc.a           mhc.b mhc.class antigen.epitope  \
# 0      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# 1      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# 2      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# 3      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# 4      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# ...            ...             ...             ...       ...             ...
# 92766  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII   PQQPFPQPEQPFP
# 92767  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII   PQQPFPQPEQPFP
# 92768  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII   PQQPFPQPEQPFP
# 92769  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII   PQQPFPQPEQPFP
# 92770  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII   PQQPFPQPEQPFP
#
#       antigen.gene antigen.species   reference.id  \
# 0              Nef           HIV-1  PMID:15596521
# 1              Nef           HIV-1  PMID:15596521
# 2              Nef           HIV-1  PMID:15596521
# 3              Nef           HIV-1  PMID:15596521
# 4              Nef           HIV-1  PMID:15596521
# ...            ...             ...            ...
# 92766       Gluten           Wheat  PMID:33927715
# 92767       Gluten           Wheat  PMID:33927715
# 92768       Gluten           Wheat  PMID:33927715
# 92769       Gluten           Wheat  PMID:33927715
# 92770       Gluten           Wheat  PMID:33927715
#
#                                                   method  \
# 0      {"frequency": "", "identification": "tetramer-...
# 1      {"frequency": "", "identification": "tetramer-...
# 2      {"frequency": "", "identification": "tetramer-...
# 3      {"frequency": "", "identification": "tetramer-...
# 4      {"frequency": "", "identification": "tetramer-...
# ...                                                  ...
# 92766  {"frequency": "", "identification": "tetramer-...
# 92767  {"frequency": "", "identification": "tetramer-...
# 92768  {"frequency": "", "identification": "tetramer-...
# 92769  {"frequency": "", "identification": "tetramer-...
# 92770  {"frequency": "", "identification": "tetramer-...
#
#                                                     meta  \
# 0      {"cell.subset": "CD8+", "clone.id": "", "donor...
# 1      {"cell.subset": "CD8+", "clone.id": "", "donor...
# 2      {"cell.subset": "CD8+", "clone.id": "", "donor...
# 3      {"cell.subset": "CD8+", "clone.id": "", "donor...
# 4      {"cell.subset": "CD8+", "clone.id": "", "donor...
# ...                                                  ...
# 92766  {"cell.subset": "CD4+", "clone.id": "", "donor...
# 92767  {"cell.subset": "CD4+", "clone.id": "", "donor...
# 92768  {"cell.subset": "CD4+", "clone.id": "", "donor...
# 92769  {"cell.subset": "CD4+", "clone.id": "", "donor...
# 92770  {"cell.subset": "CD4+", "clone.id": "", "donor...
#
#                                                  cdr3fix  vdjdb.score  \
# 0      {"cdr3": "CIVRAPGRADMRF", "cdr3_old": "CIVRAPG...            2
# 1      {"cdr3": "CASSYLPGQGDHYSNQPQHF", "cdr3_old": "...            2
# 2      {"cdr3": "CASSFEAGQGFFSNQPQHF", "cdr3_old": "C...            2
# 3      {"cdr3": "CAVPSGAGSYQLTF", "cdr3_old": "CAVPSG...            2
# 4      {"cdr3": "CASSFEPGQGFYSNQPQHF", "cdr3_old": "C...            2
# ...                                                  ...          ...
# 92766  {"cdr3": "CASSPGQGGDNEQFF", "cdr3_old": "CASSP...            0
# 92767  {"cdr3": "CAPQGATNKLIF", "cdr3_old": "CAPQGATN...            2
# 92768  {"cdr3": "CASSLGAGGQETQYF", "cdr3_old": "CASSL...            2
# 92769  {"cdr3": "CLVGGSGGYNKLIF", "cdr3_old": "CLVGGS...            0
# 92770  {"cdr3": "CASSSTAQETQYF", "cdr3_old": "CASSSTA...            0
#
#       web.method web.method.seq web.cdr3fix.nc web.cdr3fix.unmp
# 0           sort         sanger             no               no
# 1           sort         sanger             no               no
# 2           sort         sanger             no               no
# 3           sort         sanger             no               no
# 4           sort         sanger             no               no
# ...          ...            ...            ...              ...
# 92766       sort     singlecell             no               no
# 92767       sort     singlecell             no               no
# 92768       sort     singlecell             no               no
# 92769       sort     singlecell             no               no
# 92770       sort     singlecell             no               no
#
# [92771 rows x 21 columns]>

# %%
columns_to_drop = ['reference.id', 'method', 'meta','cdr3fix','web.method','web.method.seq','web.cdr3fix.nc','web.cdr3fix.unmp','mhc.a','mhc.b','mhc.class']
data.drop(columns=columns_to_drop, inplace=True)
data
# Out:
#        complex.id gene                  cdr3       v.segm      j.segm  \
# 0               1  TRA         CIVRAPGRADMRF  TRAV26-1*01   TRAJ43*01
# 1               1  TRB  CASSYLPGQGDHYSNQPQHF    TRBV13*01  TRBJ1-5*01
# 2               0  TRB   CASSFEAGQGFFSNQPQHF    TRBV13*01  TRBJ1-5*01
# 3               2  TRA        CAVPSGAGSYQLTF    TRAV20*01   TRAJ28*01
# 4               2  TRB   CASSFEPGQGFYSNQPQHF    TRBV13*01  TRBJ1-5*01
# ...           ...  ...                   ...          ...         ...
# 92766       30592  TRB       CASSPGQGGDNEQFF   TRBV7-3*01  TRBJ2-1*01
# 92767       30593  TRA          CAPQGATNKLIF  TRAV12-2*01   TRAJ32*01
# 92768       30593  TRB       CASSLGAGGQETQYF   TRBV5-1*01  TRBJ2-5*01
# 92769       30594  TRA        CLVGGSGGYNKLIF     TRAV4*01    TRAJ4*01
# 92770       30594  TRB         CASSSTAQETQYF  TRBV11-2*01  TRBJ2-5*01
#
#            species antigen.epitope antigen.gene antigen.species  vdjdb.score
# 0      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# 1      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# 2      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# 3      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# 4      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# ...            ...             ...          ...             ...          ...
# 92766  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            0
# 92767  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            2
# 92768  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            2
# 92769  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            0
# 92770  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            0
#
# [92771 rows x 10 columns]

# %%
# Filter by species
data_human = data[data['species'] == 'HomoSapiens']
data_mouse = data[data['species'] == 'MusMusculus']
data_monkey = data[data['species'] == 'MacacaMulatta'] 
#next analysis is for humans only
df=data_human
df
# Out:
#        complex.id gene                  cdr3       v.segm      j.segm  \
# 0               1  TRA         CIVRAPGRADMRF  TRAV26-1*01   TRAJ43*01
# 1               1  TRB  CASSYLPGQGDHYSNQPQHF    TRBV13*01  TRBJ1-5*01
# 2               0  TRB   CASSFEAGQGFFSNQPQHF    TRBV13*01  TRBJ1-5*01
# 3               2  TRA        CAVPSGAGSYQLTF    TRAV20*01   TRAJ28*01
# 4               2  TRB   CASSFEPGQGFYSNQPQHF    TRBV13*01  TRBJ1-5*01
# ...           ...  ...                   ...          ...         ...
# 92766       30592  TRB       CASSPGQGGDNEQFF   TRBV7-3*01  TRBJ2-1*01
# 92767       30593  TRA          CAPQGATNKLIF  TRAV12-2*01   TRAJ32*01
# 92768       30593  TRB       CASSLGAGGQETQYF   TRBV5-1*01  TRBJ2-5*01
# 92769       30594  TRA        CLVGGSGGYNKLIF     TRAV4*01    TRAJ4*01
# 92770       30594  TRB         CASSSTAQETQYF  TRBV11-2*01  TRBJ2-5*01
#
#            species antigen.epitope antigen.gene antigen.species  vdjdb.score
# 0      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# 1      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# 2      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# 3      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# 4      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# ...            ...             ...          ...             ...          ...
# 92766  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            0
# 92767  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            2
# 92768  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            2
# 92769  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            0
# 92770  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            0
#
# [85329 rows x 10 columns]

# %%
from tcrdist.repertoire import TCRrep
import pandas as pd
# 针对alpha链和beta链的数据进行筛选
data_alpha = df[df['gene'] == 'TRA'].copy()
data_beta = df[df['gene'] == 'TRB'].copy()
# 将数据列重命名以匹配TCRrep的期望格式
data_alpha.rename(columns={'cdr3': 'cdr3_a_aa', 'v.segm': 'v_a_gene', 'j.segm': 'j_a_gene'}, inplace=True)
data_beta.rename(columns={'cdr3': 'cdr3_b_aa', 'v.segm': 'v_b_gene', 'j.segm': 'j_b_gene'}, inplace=True)
data_alpha
# Out:
#        complex.id gene       cdr3_a_aa         v_a_gene   j_a_gene  \
# 0               1  TRA   CIVRAPGRADMRF      TRAV26-1*01  TRAJ43*01
# 3               2  TRA  CAVPSGAGSYQLTF        TRAV20*01  TRAJ28*01
# 5               3  TRA     CAVKASGSRLT         TRAV2*01        NaN
# 7               4  TRA   CAYRPPGTYKYIF  TRAV38-2/DV8*01  TRAJ40*01
# 9               5  TRA   CIVRAPGRADMRF      TRAV26-1*01  TRAJ43*01
# ...           ...  ...             ...              ...        ...
# 92761       30590  TRA   CMDEGGSNYKLTF      TRAV26-1*01  TRAJ53*01
# 92763       30591  TRA     CSLYNNNDMRF      TRAV26-1*01  TRAJ43*01
# 92765       30592  TRA   CALSTDSWGKLQF         TRAV6*01  TRAJ24*01
# 92767       30593  TRA    CAPQGATNKLIF      TRAV12-2*01  TRAJ32*01
# 92769       30594  TRA  CLVGGSGGYNKLIF         TRAV4*01   TRAJ4*01
#
#            species antigen.epitope antigen.gene antigen.species  vdjdb.score
# 0      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# 3      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# 5      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# 7      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# 9      HomoSapiens        FLKEQGGL          Nef           HIV-1            2
# ...            ...             ...          ...             ...          ...
# 92761  HomoSapiens    PQPELPYPQPQL       Gluten           Wheat            0
# 92763  HomoSapiens    PQPELPYPQPQL       Gluten           Wheat            0
# 92765  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            0
# 92767  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            2
# 92769  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            0
#
# [35643 rows x 10 columns]

# %%
#创造‘TCRrep’类
#alpha chain
tr_alpha = TCRrep(cell_df=data_alpha, 
                  organism='human', 
                  chains=['alpha'], 
                  db_file='alphabeta_gammadelta_db.tsv',
                  compute_distances = False)
tr_alpha.cpus = 2
tr_alpha.compute_sparse_rect_distances(radius = 50, chunk_size = 100)
tr_alpha.rw_alpha
print(tr_alpha.rw_alpha)
# Out:
# /Users/lulu/anaconda3/lib/python3.11/site-packages/tcrdist/repertoire.py:159: UserWarning: cell_df needs a counts column to track clonal number of frequency
#
#   self._validate_cell_df()
# /Users/lulu/anaconda3/lib/python3.11/site-packages/tcrdist/repertoire.py:791: UserWarning: No 'count' column provided; count column set to 1
#   warnings.warn("No 'count' column provided; count column set to 1")
# /Users/lulu/anaconda3/lib/python3.11/site-packages/tcrdist/repertoire.py:500: UserWarning: nan gene was not recognized in reference db no cdr seq could be inferred
#   f0 = lambda v : self._map_gene_to_reference_seq2(gene = v,
# /Users/lulu/anaconda3/lib/python3.11/site-packages/tcrdist/repertoire.py:504: UserWarning: nan gene was not recognized in reference db no cdr seq could be inferred
#   f1 = lambda v : self._map_gene_to_reference_seq2(gene = v,
# /Users/lulu/anaconda3/lib/python3.11/site-packages/tcrdist/repertoire.py:508: UserWarning: nan gene was not recognized in reference db no cdr seq could be inferred
#   f2 = lambda v : self._map_gene_to_reference_seq2(gene = v,
# /Users/lulu/anaconda3/lib/python3.11/site-packages/tcrdist/repertoire.py:190: UserWarning: Not all cells/sequences could be grouped into clones.921 of 35643 were not captured. This occurs when any of the values in the index columns are null or missing for a given sequence. To see entries with missing values use: tcrdist.repertoire.TCRrep._show_incomplete()
#   self.deduplicate()
#   0%|          | 0/341 [00:00<?, ?it/s]
#   (0, 0)	-1
#   (0, 4063)	48
#   (0, 4165)	48
#   (0, 4210)	48
#   (0, 10837)	45
#   (0, 11916)	48
#   (0, 15005)	45
#   (0, 15959)	48
#   (0, 21215)	48
#   (0, 25719)	45
#   (0, 26797)	48
#   (0, 27666)	45
#   (1, 1)	-1
#   (1, 338)	47
#   (1, 1423)	33
#   (1, 2699)	47
#   (1, 2962)	50
#   (1, 3021)	-1
#   (1, 3394)	36
#   (1, 3407)	24
#   (1, 3731)	36
#   (1, 3898)	36
#   (1, 4127)	33
#   (1, 4137)	36
#   (1, 4154)	36
#   :	:
#   (34027, 27338)	48
#   (34027, 27814)	48
#   (34027, 28004)	36
#   (34027, 28657)	21
#   (34027, 29576)	21
#   (34027, 29579)	45
#   (34027, 29632)	48
#   (34027, 29640)	48
#   (34027, 29795)	36
#   (34027, 30746)	24
#   (34027, 30747)	24
#   (34027, 30749)	36
#   (34027, 31729)	48
#   (34027, 31926)	48
#   (34027, 32652)	24
#   (34027, 32988)	36
#   (34027, 33043)	48
#   (34027, 33383)	48
#   (34027, 33794)	48
#   (34027, 33803)	48
#   (34027, 33904)	36
#   (34027, 34001)	9
#   (34027, 34002)	-1
#   (34027, 34003)	-1
#   (34027, 34027)	-1

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 使用 seaborn 的 heatmap 函数来可视化距离矩阵
sns.heatmap(tr_alpha.pw_alpha)
plt.title("TCR Alpha Chain Pairwise Distance Matrix")
plt.show()

# %% [markdown]
# 下一步计算beta链

# %%
#beta chain
tr_beta = TCRrep(cell_df=data_beta, 
                 organism='human', 
                 chains=['beta'], 
                 db_file='alphabeta_gammadelta_db.tsv',
                 compute_distances = False)
tr_beta.cpus = 2
tr_beta.compute_sparse_rect_distances(radius = 50, chunk_size = 100)
tr_beta.rw_beta
print(tr_beta.rw_beta)
# Out:
# /Users/lulu/anaconda3/lib/python3.11/site-packages/tcrdist/repertoire.py:159: UserWarning: cell_df needs a counts column to track clonal number of frequency
#
#   self._validate_cell_df()
# /Users/lulu/anaconda3/lib/python3.11/site-packages/tcrdist/repertoire.py:791: UserWarning: No 'count' column provided; count column set to 1
#   warnings.warn("No 'count' column provided; count column set to 1")
# /Users/lulu/anaconda3/lib/python3.11/site-packages/tcrdist/repertoire.py:500: UserWarning: nan gene was not recognized in reference db no cdr seq could be inferred
#   f0 = lambda v : self._map_gene_to_reference_seq2(gene = v,
# /Users/lulu/anaconda3/lib/python3.11/site-packages/tcrdist/repertoire.py:504: UserWarning: nan gene was not recognized in reference db no cdr seq could be inferred
#   f1 = lambda v : self._map_gene_to_reference_seq2(gene = v,
# /Users/lulu/anaconda3/lib/python3.11/site-packages/tcrdist/repertoire.py:508: UserWarning: nan gene was not recognized in reference db no cdr seq could be inferred
#   f2 = lambda v : self._map_gene_to_reference_seq2(gene = v,
# /Users/lulu/anaconda3/lib/python3.11/site-packages/tcrdist/repertoire.py:190: UserWarning: Not all cells/sequences could be grouped into clones.137 of 49686 were not captured. This occurs when any of the values in the index columns are null or missing for a given sequence. To see entries with missing values use: tcrdist.repertoire.TCRrep._show_incomplete()
#   self.deduplicate()
#   0%|          | 0/466 [00:00<?, ?it/s]
#   (0, 0)	-1
#   (0, 1119)	30
#   (0, 2338)	36
#   (0, 3750)	36
#   (0, 3804)	48
#   (0, 4948)	48
#   (0, 4955)	48
#   (0, 4958)	36
#   (0, 4979)	48
#   (0, 4983)	48
#   (0, 5137)	40
#   (0, 5138)	48
#   (0, 5147)	48
#   (0, 5150)	45
#   (0, 5152)	39
#   (0, 7736)	39
#   (0, 7991)	36
#   (0, 13275)	48
#   (0, 13712)	48
#   (0, 18305)	40
#   (0, 21551)	48
#   (0, 22801)	48
#   (0, 24284)	27
#   (0, 26186)	48
#   (0, 29295)	48
#   :	:
#   (46564, 21306)	48
#   (46564, 22276)	48
#   (46564, 24012)	43
#   (46564, 24745)	36
#   (46564, 25633)	48
#   (46564, 25999)	36
#   (46564, 26492)	48
#   (46564, 26890)	36
#   (46564, 27287)	36
#   (46564, 27406)	48
#   (46564, 27482)	36
#   (46564, 27702)	48
#   (46564, 27796)	48
#   (46564, 28088)	36
#   (46564, 28650)	36
#   (46564, 30577)	48
#   (46564, 31934)	33
#   (46564, 34322)	48
#   (46564, 34565)	47
#   (46564, 34581)	48
#   (46564, 38066)	42
#   (46564, 39772)	48
#   (46564, 40214)	24
#   (46564, 41125)	42
#   (46564, 46564)	-1

# %% [markdown]
# 下一步计算alpha，beta配对后的距离矩阵

# %%
# 通过complex.id进行合并，假设每个complex.id对应一对alpha和beta链
# 确保complex.id不等于0
data_alpha = data_alpha[data_alpha['complex.id'] != 0]
data_beta = data_beta[data_beta['complex.id'] != 0]
# 合并alpha和beta链数据（拼接）
data_combined = pd.merge(data_alpha, data_beta, on='complex.id', suffixes=('_alpha', '_beta'))
data_combined['combined_feature'] = data_combined['cdr3_a_aa'] + "_" + data_combined['cdr3_b_aa']
data_combined
# Out:
#        complex.id gene_alpha       cdr3_a_aa         v_a_gene   j_a_gene  \
# 0               1        TRA   CIVRAPGRADMRF      TRAV26-1*01  TRAJ43*01
# 1               2        TRA  CAVPSGAGSYQLTF        TRAV20*01  TRAJ28*01
# 2               3        TRA     CAVKASGSRLT         TRAV2*01        NaN
# 3               4        TRA   CAYRPPGTYKYIF  TRAV38-2/DV8*01  TRAJ40*01
# 4               5        TRA   CIVRAPGRADMRF      TRAV26-1*01  TRAJ43*01
# ...           ...        ...             ...              ...        ...
# 28339       30590        TRA   CMDEGGSNYKLTF      TRAV26-1*01  TRAJ53*01
# 28340       30591        TRA     CSLYNNNDMRF      TRAV26-1*01  TRAJ43*01
# 28341       30592        TRA   CALSTDSWGKLQF         TRAV6*01  TRAJ24*01
# 28342       30593        TRA    CAPQGATNKLIF      TRAV12-2*01  TRAJ32*01
# 28343       30594        TRA  CLVGGSGGYNKLIF         TRAV4*01   TRAJ4*01
#
#       species_alpha antigen.epitope_alpha antigen.gene_alpha  \
# 0       HomoSapiens              FLKEKGGL                Nef
# 1       HomoSapiens              FLKEKGGL                Nef
# 2       HomoSapiens              FLKEKGGL                Nef
# 3       HomoSapiens              FLKEKGGL                Nef
# 4       HomoSapiens              FLKEQGGL                Nef
# ...             ...                   ...                ...
# 28339   HomoSapiens          PQPELPYPQPQL             Gluten
# 28340   HomoSapiens          PQPELPYPQPQL             Gluten
# 28341   HomoSapiens         PQQPFPQPEQPFP             Gluten
# 28342   HomoSapiens         PQQPFPQPEQPFP             Gluten
# 28343   HomoSapiens         PQQPFPQPEQPFP             Gluten
#
#       antigen.species_alpha  vdjdb.score_alpha  count_alpha gene_beta  \
# 0                     HIV-1                  2            1       TRB
# 1                     HIV-1                  2            1       TRB
# 2                     HIV-1                  2            1       TRB
# 3                     HIV-1                  2            1       TRB
# 4                     HIV-1                  2            1       TRB
# ...                     ...                ...          ...       ...
# 28339                 Wheat                  0            1       TRB
# 28340                 Wheat                  0            1       TRB
# 28341                 Wheat                  0            1       TRB
# 28342                 Wheat                  2            1       TRB
# 28343                 Wheat                  0            1       TRB
#
#                   cdr3_b_aa     v_b_gene    j_b_gene species_beta  \
# 0      CASSYLPGQGDHYSNQPQHF    TRBV13*01  TRBJ1-5*01  HomoSapiens
# 1       CASSFEPGQGFYSNQPQHF    TRBV13*01  TRBJ1-5*01  HomoSapiens
# 2      CASSYEPGQVSHYSNQPQHF    TRBV13*01  TRBJ1-5*01  HomoSapiens
# 3            CASSALASLNEQFF    TRBV14*01  TRBJ2-1*01  HomoSapiens
# 4      CASSYLPGQGDHYSNQPQHF    TRBV13*01  TRBJ1-5*01  HomoSapiens
# ...                     ...          ...         ...          ...
# 28339         CASSVRSTDTQYF   TRBV7-2*01  TRBJ2-3*01  HomoSapiens
# 28340         CASSLRYTDTQYF   TRBV7-2*01  TRBJ2-3*01  HomoSapiens
# 28341       CASSPGQGGDNEQFF   TRBV7-3*01  TRBJ2-1*01  HomoSapiens
# 28342       CASSLGAGGQETQYF   TRBV5-1*01  TRBJ2-5*01  HomoSapiens
# 28343         CASSSTAQETQYF  TRBV11-2*01  TRBJ2-5*01  HomoSapiens
#
#       antigen.epitope_beta antigen.gene_beta antigen.species_beta  \
# 0                 FLKEKGGL               Nef                HIV-1
# 1                 FLKEKGGL               Nef                HIV-1
# 2                 FLKEKGGL               Nef                HIV-1
# 3                 FLKEKGGL               Nef                HIV-1
# 4                 FLKEQGGL               Nef                HIV-1
# ...                    ...               ...                  ...
# 28339         PQPELPYPQPQL            Gluten                Wheat
# 28340         PQPELPYPQPQL            Gluten                Wheat
# 28341        PQQPFPQPEQPFP            Gluten                Wheat
# 28342        PQQPFPQPEQPFP            Gluten                Wheat
# 28343        PQQPFPQPEQPFP            Gluten                Wheat
#
#        vdjdb.score_beta  count_beta                    combined_feature
# 0                     2           1  CIVRAPGRADMRF_CASSYLPGQGDHYSNQPQHF
# 1                     2           1  CAVPSGAGSYQLTF_CASSFEPGQGFYSNQPQHF
# 2                     2           1    CAVKASGSRLT_CASSYEPGQVSHYSNQPQHF
# 3                     2           1        CAYRPPGTYKYIF_CASSALASLNEQFF
# 4                     2           1  CIVRAPGRADMRF_CASSYLPGQGDHYSNQPQHF
# ...                 ...         ...                                 ...
# 28339                 0           1         CMDEGGSNYKLTF_CASSVRSTDTQYF
# 28340                 0           1           CSLYNNNDMRF_CASSLRYTDTQYF
# 28341                 0           1       CALSTDSWGKLQF_CASSPGQGGDNEQFF
# 28342                 2           1        CAPQGATNKLIF_CASSLGAGGQETQYF
# 28343                 0           1        CLVGGSGGYNKLIF_CASSSTAQETQYF
#
# [28344 rows x 22 columns]

# %%
tr = TCRrep(cell_df = data_combined,
            organism = 'human', 
            chains = ['beta'],  # 这里chains参数是必须的，但因为我们用的是综合特征，所以实际选择哪个链并不重要
            db_file = 'alphabeta_gammadelta_db.tsv', 
            compute_distances = False)
tr.cpus = 2
tr.compute_sparse_rect_distances(radius = 50, chunk_size = 100)
tr.rw_beta
print(tr.rw_beta)
# Out:
# /Users/lulu/anaconda3/lib/python3.11/site-packages/tcrdist/repertoire.py:159: UserWarning: cell_df needs a counts column to track clonal number of frequency
#
#   self._validate_cell_df()
# /Users/lulu/anaconda3/lib/python3.11/site-packages/tcrdist/repertoire.py:791: UserWarning: No 'count' column provided; count column set to 1
#   warnings.warn("No 'count' column provided; count column set to 1")
# /Users/lulu/anaconda3/lib/python3.11/site-packages/tcrdist/repertoire.py:500: UserWarning: nan gene was not recognized in reference db no cdr seq could be inferred
#   f0 = lambda v : self._map_gene_to_reference_seq2(gene = v,
# /Users/lulu/anaconda3/lib/python3.11/site-packages/tcrdist/repertoire.py:504: UserWarning: nan gene was not recognized in reference db no cdr seq could be inferred
#   f1 = lambda v : self._map_gene_to_reference_seq2(gene = v,
# /Users/lulu/anaconda3/lib/python3.11/site-packages/tcrdist/repertoire.py:508: UserWarning: nan gene was not recognized in reference db no cdr seq could be inferred
#   f2 = lambda v : self._map_gene_to_reference_seq2(gene = v,
# /Users/lulu/anaconda3/lib/python3.11/site-packages/tcrdist/repertoire.py:190: UserWarning: Not all cells/sequences could be grouped into clones.794 of 28344 were not captured. This occurs when any of the values in the index columns are null or missing for a given sequence. To see entries with missing values use: tcrdist.repertoire.TCRrep._show_incomplete()
#   self.deduplicate()
#   0%|          | 0/276 [00:00<?, ?it/s]
#   (0, 0)	-1
#   (0, 1)	39
#   (0, 3)	-1
#   (0, 4)	39
#   (0, 5)	-1
#   (0, 6)	39
#   (0, 7)	-1
#   (0, 8)	39
#   (1, 0)	39
#   (1, 1)	-1
#   (1, 3)	39
#   (1, 4)	-1
#   (1, 5)	39
#   (1, 6)	-1
#   (1, 7)	39
#   (1, 8)	-1
#   (2, 2)	-1
#   (2, 2098)	45
#   (2, 24292)	48
#   (2, 24299)	48
#   (2, 25784)	48
#   (2, 25943)	48
#   (2, 26562)	48
#   (3, 0)	-1
#   (3, 1)	39
#   :	:
#   (27549, 1992)	42
#   (27549, 2792)	48
#   (27549, 3748)	48
#   (27549, 5445)	43
#   (27549, 6165)	36
#   (27549, 7048)	48
#   (27549, 7412)	36
#   (27549, 7904)	48
#   (27549, 8297)	36
#   (27549, 8689)	36
#   (27549, 8808)	48
#   (27549, 8883)	36
#   (27549, 9100)	48
#   (27549, 9193)	48
#   (27549, 9480)	36
#   (27549, 10034)	36
#   (27549, 11924)	48
#   (27549, 13255)	33
#   (27549, 15593)	48
#   (27549, 15831)	47
#   (27549, 19269)	42
#   (27549, 20941)	48
#   (27549, 21374)	24
#   (27549, 22269)	42
#   (27549, 27549)	-1
