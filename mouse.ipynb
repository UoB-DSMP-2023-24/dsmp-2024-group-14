# %%
import pandas as pd
pd.set_option('display.max_columns', None)
data=pd.read_csv('./vdjdb.txt',sep='\t', header=0)

data
# Out:
#        complex.id gene                  cdr3       v.segm      j.segm  \
# 0               1  TRA         CIVRAPGRADMRF  TRAV26-1*01   TRAJ43*01
# 1               1  TRB  CASSYLPGQGDHYSNQPQHF    TRBV13*01  TRBJ1-5*01
# 2               0  TRB   CASSFEAGQGFFSNQPQHF    TRBV13*01  TRBJ1-5*01
# 3               2  TRA        CAVPSGAGSYQLTF    TRAV20*01   TRAJ28*01
# 4               2  TRB   CASSFEPGQGFYSNQPQHF    TRBV13*01  TRBJ1-5*01
# ...           ...  ...                   ...          ...         ...
# 92766       30592  TRB       CASSPGQGGDNEQFF   TRBV7-3*01  TRBJ2-1*01
# 92767       30593  TRA          CAPQGATNKLIF  TRAV12-2*01   TRAJ32*01
# 92768       30593  TRB       CASSLGAGGQETQYF   TRBV5-1*01  TRBJ2-5*01
# 92769       30594  TRA        CLVGGSGGYNKLIF     TRAV4*01    TRAJ4*01
# 92770       30594  TRB         CASSSTAQETQYF  TRBV11-2*01  TRBJ2-5*01
#
#            species           mhc.a           mhc.b mhc.class antigen.epitope  \
# 0      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# 1      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# 2      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# 3      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# 4      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# ...            ...             ...             ...       ...             ...
# 92766  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII   PQQPFPQPEQPFP
# 92767  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII   PQQPFPQPEQPFP
# 92768  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII   PQQPFPQPEQPFP
# 92769  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII   PQQPFPQPEQPFP
# 92770  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII   PQQPFPQPEQPFP
#
#       antigen.gene antigen.species   reference.id  \
# 0              Nef           HIV-1  PMID:15596521
# 1              Nef           HIV-1  PMID:15596521
# 2              Nef           HIV-1  PMID:15596521
# 3              Nef           HIV-1  PMID:15596521
# 4              Nef           HIV-1  PMID:15596521
# ...            ...             ...            ...
# 92766       Gluten           Wheat  PMID:33927715
# 92767       Gluten           Wheat  PMID:33927715
# 92768       Gluten           Wheat  PMID:33927715
# 92769       Gluten           Wheat  PMID:33927715
# 92770       Gluten           Wheat  PMID:33927715
#
#                                                   method  \
# 0      {"frequency": "", "identification": "tetramer-...
# 1      {"frequency": "", "identification": "tetramer-...
# 2      {"frequency": "", "identification": "tetramer-...
# 3      {"frequency": "", "identification": "tetramer-...
# 4      {"frequency": "", "identification": "tetramer-...
# ...                                                  ...
# 92766  {"frequency": "", "identification": "tetramer-...
# 92767  {"frequency": "", "identification": "tetramer-...
# 92768  {"frequency": "", "identification": "tetramer-...
# 92769  {"frequency": "", "identification": "tetramer-...
# 92770  {"frequency": "", "identification": "tetramer-...
#
#                                                     meta  \
# 0      {"cell.subset": "CD8+", "clone.id": "", "donor...
# 1      {"cell.subset": "CD8+", "clone.id": "", "donor...
# 2      {"cell.subset": "CD8+", "clone.id": "", "donor...
# 3      {"cell.subset": "CD8+", "clone.id": "", "donor...
# 4      {"cell.subset": "CD8+", "clone.id": "", "donor...
# ...                                                  ...
# 92766  {"cell.subset": "CD4+", "clone.id": "", "donor...
# 92767  {"cell.subset": "CD4+", "clone.id": "", "donor...
# 92768  {"cell.subset": "CD4+", "clone.id": "", "donor...
# 92769  {"cell.subset": "CD4+", "clone.id": "", "donor...
# 92770  {"cell.subset": "CD4+", "clone.id": "", "donor...
#
#                                                  cdr3fix  vdjdb.score  \
# 0      {"cdr3": "CIVRAPGRADMRF", "cdr3_old": "CIVRAPG...            2
# 1      {"cdr3": "CASSYLPGQGDHYSNQPQHF", "cdr3_old": "...            2
# 2      {"cdr3": "CASSFEAGQGFFSNQPQHF", "cdr3_old": "C...            2
# 3      {"cdr3": "CAVPSGAGSYQLTF", "cdr3_old": "CAVPSG...            2
# 4      {"cdr3": "CASSFEPGQGFYSNQPQHF", "cdr3_old": "C...            2
# ...                                                  ...          ...
# 92766  {"cdr3": "CASSPGQGGDNEQFF", "cdr3_old": "CASSP...            0
# 92767  {"cdr3": "CAPQGATNKLIF", "cdr3_old": "CAPQGATN...            2
# 92768  {"cdr3": "CASSLGAGGQETQYF", "cdr3_old": "CASSL...            2
# 92769  {"cdr3": "CLVGGSGGYNKLIF", "cdr3_old": "CLVGGS...            0
# 92770  {"cdr3": "CASSSTAQETQYF", "cdr3_old": "CASSSTA...            0
#
#       web.method web.method.seq web.cdr3fix.nc web.cdr3fix.unmp
# 0           sort         sanger             no               no
# 1           sort         sanger             no               no
# 2           sort         sanger             no               no
# 3           sort         sanger             no               no
# 4           sort         sanger             no               no
# ...          ...            ...            ...              ...
# 92766       sort     singlecell             no               no
# 92767       sort     singlecell             no               no
# 92768       sort     singlecell             no               no
# 92769       sort     singlecell             no               no
# 92770       sort     singlecell             no               no
#
# [92771 rows x 21 columns]

# %%
columns_to_drop = ['reference.id', 'method', 'meta','cdr3fix','web.method','web.method.seq','web.cdr3fix.nc','web.cdr3fix.unmp','mhc.a','mhc.b','mhc.class']
data.drop(columns=columns_to_drop, inplace=True)
data
# Out:
#        complex.id gene                  cdr3       v.segm      j.segm  \
# 0               1  TRA         CIVRAPGRADMRF  TRAV26-1*01   TRAJ43*01
# 1               1  TRB  CASSYLPGQGDHYSNQPQHF    TRBV13*01  TRBJ1-5*01
# 2               0  TRB   CASSFEAGQGFFSNQPQHF    TRBV13*01  TRBJ1-5*01
# 3               2  TRA        CAVPSGAGSYQLTF    TRAV20*01   TRAJ28*01
# 4               2  TRB   CASSFEPGQGFYSNQPQHF    TRBV13*01  TRBJ1-5*01
# ...           ...  ...                   ...          ...         ...
# 92766       30592  TRB       CASSPGQGGDNEQFF   TRBV7-3*01  TRBJ2-1*01
# 92767       30593  TRA          CAPQGATNKLIF  TRAV12-2*01   TRAJ32*01
# 92768       30593  TRB       CASSLGAGGQETQYF   TRBV5-1*01  TRBJ2-5*01
# 92769       30594  TRA        CLVGGSGGYNKLIF     TRAV4*01    TRAJ4*01
# 92770       30594  TRB         CASSSTAQETQYF  TRBV11-2*01  TRBJ2-5*01
#
#            species antigen.epitope antigen.gene antigen.species  vdjdb.score
# 0      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# 1      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# 2      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# 3      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# 4      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# ...            ...             ...          ...             ...          ...
# 92766  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            0
# 92767  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            2
# 92768  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            2
# 92769  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            0
# 92770  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            0
#
# [92771 rows x 10 columns]

# %%
data.isnull().sum()
# Out:
# complex.id            0
# gene                  0
# cdr3                  0
# v.segm              101
# j.segm             1145
# species               0
# antigen.epitope       0
# antigen.gene         62
# antigen.species       0
# vdjdb.score           0
# dtype: int64

# %%
data=data.dropna() # dropping rows with any column having null values

# %%
data
# Out:
#        complex.id gene                  cdr3       v.segm      j.segm  \
# 0               1  TRA         CIVRAPGRADMRF  TRAV26-1*01   TRAJ43*01
# 1               1  TRB  CASSYLPGQGDHYSNQPQHF    TRBV13*01  TRBJ1-5*01
# 2               0  TRB   CASSFEAGQGFFSNQPQHF    TRBV13*01  TRBJ1-5*01
# 3               2  TRA        CAVPSGAGSYQLTF    TRAV20*01   TRAJ28*01
# 4               2  TRB   CASSFEPGQGFYSNQPQHF    TRBV13*01  TRBJ1-5*01
# ...           ...  ...                   ...          ...         ...
# 92766       30592  TRB       CASSPGQGGDNEQFF   TRBV7-3*01  TRBJ2-1*01
# 92767       30593  TRA          CAPQGATNKLIF  TRAV12-2*01   TRAJ32*01
# 92768       30593  TRB       CASSLGAGGQETQYF   TRBV5-1*01  TRBJ2-5*01
# 92769       30594  TRA        CLVGGSGGYNKLIF     TRAV4*01    TRAJ4*01
# 92770       30594  TRB         CASSSTAQETQYF  TRBV11-2*01  TRBJ2-5*01
#
#            species antigen.epitope antigen.gene antigen.species  vdjdb.score
# 0      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# 1      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# 2      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# 3      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# 4      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# ...            ...             ...          ...             ...          ...
# 92766  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            0
# 92767  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            2
# 92768  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            2
# 92769  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            0
# 92770  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            0
#
# [91550 rows x 10 columns]

# %%
# Filter by species
data_human = data[data['species'] == 'HomoSapiens']
data_mouse = data[data['species'] == 'MusMusculus']
data_monkey = data[data['species'] == 'MacacaMulatta'] 
#next analysis is for mouse only
df=data_mouse
df
# Out:
#        complex.id gene              cdr3       v.segm      j.segm  \
# 1270          105  TRB     CASGGQGRAEQFF  TRBV13-2*01  TRBJ2-1*01
# 1271          106  TRA  CAMRGDYGGSGNKLIF    TRAV16*01   TRAJ32*01
# 1272          106  TRB    CTCSADRVGNTLYF     TRBV1*01  TRBJ1-3*01
# 1275          108  TRA      CAVSGFASALTF   TRAV9-4*01   TRAJ35*01
# 1276          108  TRB       CASGGGGTLYF  TRBV13-2*01  TRBJ2-4*01
# ...           ...  ...               ...          ...         ...
# 92643           0  TRB    CASSDWGSAETLYF  TRBV13-3*01  TRBJ2-3*01
# 92644           0  TRA     CAARGYNQGKLIF  TRAV14-2*01   TRAJ23*01
# 92645           0  TRA     CATSDTNAYKVIF   TRAV8-2*01   TRAJ30*01
# 92646           0  TRA   CALSDTGANTGKLTF   TRAV6-5*01   TRAJ52*01
# 92647           0  TRA     CALRGNNNNRIFF  TRAV9D-4*01   TRAJ31*01
#
#            species   antigen.epitope    antigen.gene    antigen.species  \
# 1270   MusMusculus  GNSHRGAIEWEGIESG  Ovotransferrin       GallusGallus
# 1271   MusMusculus          INFDFNTI          Kctd20        MusMusculus
# 1272   MusMusculus          INFDFNTI          Kctd20        MusMusculus
# 1275   MusMusculus          SIYRYYGL       Synthetic          Synthetic
# 1276   MusMusculus          SIYRYYGL       Synthetic          Synthetic
# ...            ...               ...             ...                ...
# 92643  MusMusculus         SQLLNAKYL           GAP50  PlasmodiumBerghei
# 92644  MusMusculus         SQLLNAKYL           GAP50  PlasmodiumBerghei
# 92645  MusMusculus         SQLLNAKYL           GAP50  PlasmodiumBerghei
# 92646  MusMusculus         SQLLNAKYL           GAP50  PlasmodiumBerghei
# 92647  MusMusculus         SQLLNAKYL           GAP50  PlasmodiumBerghei
#
#        vdjdb.score
# 1270             3
# 1271             3
# 1272             3
# 1275             3
# 1276             3
# ...            ...
# 92643            0
# 92644            1
# 92645            1
# 92646            0
# 92647            0
#
# [5247 rows x 10 columns]

# %%
df['antigen.epitope'].value_counts()
# Out:
# SSYRRPVGI               1304
# SSLENFRAYV               867
# ASNENMETM                636
# HGIRNASFI                569
# SSPPMFRV                 498
# LSLRNPILV                302
# SQLLNAKYL                241
# RALEYKNL                 209
# TVYGFCLL                 175
# KAVYNFATC                135
# SYIGSINNI                 64
# NAITNAKII                 61
# RGYVYQGL                  25
# RGYVYEGL                  14
# KGYVYQGL                  13
# SIINFEKL                  12
# QLSPFPFDL                  8
# RVSYYGPKTSPVQ              8
# FEAQKAKANKAVD              8
# IGYVYQGL                   7
# EQYKFYSV                   6
# RGGASQYRPSQ                4
# ADLIAYLKQATKG              4
# RGYVYKGL                   4
# RGYVYDGL                   3
# VVVGAVGVGK                 3
# VVVGADGVGK                 2
# VSYYGPKTSPVQ               2
# KAPYNFATM                  2
# KAPYDYAPI                  2
# LVERLYLVCGGEG              2
# ADSLSFFSSSIKRGGGSLVP       2
# VVGAVGVGK                  2
# KAVYNFATM                  2
# KAVANFATM                  2
# KAPFNFATM                  2
# FEAQKAKANKAV               2
# SIYRYYGL                   2
# KVITFIDL                   2
# SRGGASQYRPSQ               2
# SQYYYNSL                   2
# GAMKRHGLDNYRGYSLG          2
# WIYVYRPMGCGGS              2
# PADPLAFFSSAIKGGGGSLV       2
# ADGLAYFRSSFKGG             2
# ANGVAFFLTPFKA              2
# FEAQKAKANKAVDG             2
# ADLIAYLEQATKG              2
# KAPANFATM                  2
# QLSDVPMDL                  2
# SPLDSLWWI                  2
# FLSPFWFDI                  2
# SPAEAGFFL                  2
# QPAEGGFQL                  2
# SPAPRPLDL                  2
# MPAGRPWDL                  2
# VPYMAEFGM                  2
# RGPGRAFVTI                 2
# INFDFNTI                   2
# GNSHRGAIEWEGIESG           1
# Name: antigen.epitope, dtype: int64

# %%
from tcrdist.repertoire import TCRrep
import pandas as pd
# Filter data for alpha chain and beta chain
data_alpha = df[df['gene'] == 'TRA'].copy()
data_beta = df[df['gene'] == 'TRB'].copy()
# Rename data columns to match TCRrep's expected format
data_alpha.rename(columns={'cdr3': 'cdr3_a_aa', 'v.segm': 'v_a_gene', 'j.segm': 'j_a_gene'}, inplace=True)
data_beta.rename(columns={'cdr3': 'cdr3_b_aa', 'v.segm': 'v_b_gene', 'j.segm': 'j_b_gene'}, inplace=True)
data_alpha.to_csv('data_alpha.csv')
data_alpha.to_csv('alpha.csv')
data_beta.to_csv('beta.csv')
data_beta
# Out:
#        complex.id gene           cdr3_b_aa     v_b_gene    j_b_gene  \
# 1270          105  TRB       CASGGQGRAEQFF  TRBV13-2*01  TRBJ2-1*01
# 1272          106  TRB      CTCSADRVGNTLYF     TRBV1*01  TRBJ1-3*01
# 1276          108  TRB         CASGGGGTLYF  TRBV13-2*01  TRBJ2-4*01
# 1280          110  TRB  CTCSAAPDWGASAETLYF     TRBV1*01  TRBJ2-3*01
# 1284          112  TRB         CASGGGGTLYF  TRBV13-2*01  TRBJ2-4*01
# ...           ...  ...                 ...          ...         ...
# 92639           0  TRB     CASSHWGGGYAEQFF  TRBV13-3*01  TRBJ2-1*01
# 92640           0  TRB      CASSDWGQGSDYTF  TRBV13-3*01  TRBJ1-2*01
# 92641           0  TRB       CASSDFKQDTQYF  TRBV13-3*01  TRBJ2-5*01
# 92642           0  TRB       CASSDYRVAEQFF  TRBV13-3*01  TRBJ2-1*01
# 92643           0  TRB      CASSDWGSAETLYF  TRBV13-3*01  TRBJ2-3*01
#
#            species   antigen.epitope    antigen.gene    antigen.species  \
# 1270   MusMusculus  GNSHRGAIEWEGIESG  Ovotransferrin       GallusGallus
# 1272   MusMusculus          INFDFNTI          Kctd20        MusMusculus
# 1276   MusMusculus          SIYRYYGL       Synthetic          Synthetic
# 1280   MusMusculus          KVITFIDL          Gtpbp1        MusMusculus
# 1284   MusMusculus          EQYKFYSV          Ndufa4        MusMusculus
# ...            ...               ...             ...                ...
# 92639  MusMusculus         SQLLNAKYL           GAP50  PlasmodiumBerghei
# 92640  MusMusculus         SQLLNAKYL           GAP50  PlasmodiumBerghei
# 92641  MusMusculus         SQLLNAKYL           GAP50  PlasmodiumBerghei
# 92642  MusMusculus         SQLLNAKYL           GAP50  PlasmodiumBerghei
# 92643  MusMusculus         SQLLNAKYL           GAP50  PlasmodiumBerghei
#
#        vdjdb.score
# 1270             3
# 1272             3
# 1276             3
# 1280             3
# 1284             3
# ...            ...
# 92639            0
# 92640            0
# 92641            0
# 92642            0
# 92643            0
#
# [3001 rows x 10 columns]

# %%
data_alpha
# Out:
#        complex.id gene         cdr3_a_aa     v_a_gene   j_a_gene      species  \
# 1271          106  TRA  CAMRGDYGGSGNKLIF    TRAV16*01  TRAJ32*01  MusMusculus
# 1275          108  TRA      CAVSGFASALTF   TRAV9-4*01  TRAJ35*01  MusMusculus
# 1279          110  TRA     CAARYQGGRALIF  TRAV14-1*01  TRAJ15*01  MusMusculus
# 1283          112  TRA      CAVSGFASALTF   TRAV9-4*01  TRAJ35*01  MusMusculus
# 1285          113  TRA  CAMRGDYGGSGNKLIF    TRAV16*01  TRAJ32*01  MusMusculus
# ...           ...  ...               ...          ...        ...          ...
# 92634           0  TRA        CATGNEEITF  TRAV8D-1*01  TRAJ48*01  MusMusculus
# 92644           0  TRA     CAARGYNQGKLIF  TRAV14-2*01  TRAJ23*01  MusMusculus
# 92645           0  TRA     CATSDTNAYKVIF   TRAV8-2*01  TRAJ30*01  MusMusculus
# 92646           0  TRA   CALSDTGANTGKLTF   TRAV6-5*01  TRAJ52*01  MusMusculus
# 92647           0  TRA     CALRGNNNNRIFF  TRAV9D-4*01  TRAJ31*01  MusMusculus
#
#       antigen.epitope antigen.gene    antigen.species  vdjdb.score
# 1271         INFDFNTI       Kctd20        MusMusculus            3
# 1275         SIYRYYGL    Synthetic          Synthetic            3
# 1279         KVITFIDL       Gtpbp1        MusMusculus            3
# 1283         EQYKFYSV       Ndufa4        MusMusculus            3
# 1285         RGYVYQGL            N                VSV            3
# ...               ...          ...                ...          ...
# 92634       SQLLNAKYL        GAP50  PlasmodiumBerghei            0
# 92644       SQLLNAKYL        GAP50  PlasmodiumBerghei            1
# 92645       SQLLNAKYL        GAP50  PlasmodiumBerghei            1
# 92646       SQLLNAKYL        GAP50  PlasmodiumBerghei            0
# 92647       SQLLNAKYL        GAP50  PlasmodiumBerghei            0
#
# [2246 rows x 10 columns]

# %%
data_alpha['antigen.epitope'].value_counts()
# Out:
# SSYRRPVGI               643
# SSLENFRAYV              430
# ASNENMETM               311
# HGIRNASFI               281
# SSPPMFRV                161
# LSLRNPILV               147
# TVYGFCLL                 86
# KAVYNFATC                65
# SQLLNAKYL                62
# SIINFEKL                  6
# RVSYYGPKTSPVQ             4
# QLSPFPFDL                 4
# FEAQKAKANKAVD             4
# EQYKFYSV                  3
# RGGASQYRPSQ               2
# ADLIAYLKQATKG             2
# KAVANFATM                 1
# VSYYGPKTSPVQ              1
# VVGAVGVGK                 1
# VVVGAVGVGK                1
# KAPYDYAPI                 1
# LVERLYLVCGGEG             1
# ADSLSFFSSSIKRGGGSLVP      1
# KAVYNFATM                 1
# KAPYNFATM                 1
# VVVGADGVGK                1
# KAPFNFATM                 1
# KAPANFATM                 1
# INFDFNTI                  1
# RGPGRAFVTI                1
# VPYMAEFGM                 1
# KVITFIDL                  1
# RGYVYQGL                  1
# SRGGASQYRPSQ              1
# SQYYYNSL                  1
# GAMKRHGLDNYRGYSLG         1
# WIYVYRPMGCGGS             1
# PADPLAFFSSAIKGGGGSLV      1
# ADGLAYFRSSFKGG            1
# ANGVAFFLTPFKA             1
# FEAQKAKANKAVDG            1
# FEAQKAKANKAV              1
# ADLIAYLEQATKG             1
# QLSDVPMDL                 1
# SPLDSLWWI                 1
# FLSPFWFDI                 1
# SPAEAGFFL                 1
# QPAEGGFQL                 1
# SIYRYYGL                  1
# MPAGRPWDL                 1
# SPAPRPLDL                 1
# Name: antigen.epitope, dtype: int64

# %%
data_beta['antigen.epitope'].value_counts()
# Out:
# SSYRRPVGI               661
# SSLENFRAYV              437
# SSPPMFRV                337
# ASNENMETM               325
# HGIRNASFI               288
# RALEYKNL                209
# SQLLNAKYL               179
# LSLRNPILV               155
# TVYGFCLL                 89
# KAVYNFATC                70
# SYIGSINNI                64
# NAITNAKII                61
# RGYVYQGL                 24
# RGYVYEGL                 14
# KGYVYQGL                 13
# IGYVYQGL                  7
# SIINFEKL                  6
# QLSPFPFDL                 4
# FEAQKAKANKAVD             4
# RVSYYGPKTSPVQ             4
# RGYVYKGL                  4
# EQYKFYSV                  3
# RGYVYDGL                  3
# VVVGAVGVGK                2
# ADLIAYLKQATKG             2
# RGGASQYRPSQ               2
# VVGAVGVGK                 1
# VSYYGPKTSPVQ              1
# VVVGADGVGK                1
# KAPYDYAPI                 1
# LVERLYLVCGGEG             1
# ADSLSFFSSSIKRGGGSLVP      1
# KAPYNFATM                 1
# KAVYNFATM                 1
# GNSHRGAIEWEGIESG          1
# KAPFNFATM                 1
# FEAQKAKANKAV              1
# SIYRYYGL                  1
# KVITFIDL                  1
# SRGGASQYRPSQ              1
# SQYYYNSL                  1
# GAMKRHGLDNYRGYSLG         1
# WIYVYRPMGCGGS             1
# PADPLAFFSSAIKGGGGSLV      1
# ADGLAYFRSSFKGG            1
# ANGVAFFLTPFKA             1
# FEAQKAKANKAVDG            1
# ADLIAYLEQATKG             1
# KAPANFATM                 1
# QLSDVPMDL                 1
# SPLDSLWWI                 1
# FLSPFWFDI                 1
# SPAEAGFFL                 1
# QPAEGGFQL                 1
# SPAPRPLDL                 1
# MPAGRPWDL                 1
# VPYMAEFGM                 1
# RGPGRAFVTI                1
# INFDFNTI                  1
# KAVANFATM                 1
# Name: antigen.epitope, dtype: int64

# %%
data_alpha = data_alpha[(data_alpha['antigen.epitope'] == 'SSYRRPVGI') | (data_alpha['antigen.epitope'] == 'SSLENFRAYV')| (data_alpha['antigen.epitope'] == 'ASNENMETM')| (data_alpha['antigen.epitope'] == 'HGIRNASFI')| (data_alpha['antigen.epitope'] == 'SSPPMFRV')| (data_alpha['antigen.epitope'] == 'LSLRNPILV')| (data_alpha['antigen.epitope'] == 'TVYGFCLL')| (data_alpha['antigen.epitope'] == 'KAVYNFATC')| (data_alpha['antigen.epitope'] == 'SQLLNAKYL')| (data_alpha['antigen.epitope'] == 'SIINFEKL')].copy()

# %%
data_alpha
# Out:
#        complex.id gene        cdr3_a_aa        v_a_gene   j_a_gene  \
# 1373          157  TRA    CILSGGSNYKLTF  TRAV21/DV12*01  TRAJ53*01
# 1617          279  TRA   CAASEGSGSWQLIF     TRAV14-1*01  TRAJ22*01
# 1619          280  TRA   CAASETSGSWQLIF     TRAV14-1*01  TRAJ22*01
# 1635          288  TRA      CATVYAQGLTF      TRAV8-2*01  TRAJ26*01
# 1747          344  TRA    CAAVTGNTGKLIF      TRAV4-2*01  TRAJ37*01
# ...           ...  ...              ...             ...        ...
# 92634           0  TRA       CATGNEEITF     TRAV8D-1*01  TRAJ48*01
# 92644           0  TRA    CAARGYNQGKLIF     TRAV14-2*01  TRAJ23*01
# 92645           0  TRA    CATSDTNAYKVIF      TRAV8-2*01  TRAJ30*01
# 92646           0  TRA  CALSDTGANTGKLTF      TRAV6-5*01  TRAJ52*01
# 92647           0  TRA    CALRGNNNNRIFF     TRAV9D-4*01  TRAJ31*01
#
#            species antigen.epitope antigen.gene    antigen.species  \
# 1373   MusMusculus      SSLENFRAYV           PA         InfluenzaA
# 1617   MusMusculus       ASNENMETM           NP         InfluenzaA
# 1619   MusMusculus       ASNENMETM           NP         InfluenzaA
# 1635   MusMusculus       SQLLNAKYL        GAP50  PlasmodiumBerghei
# 1747   MusMusculus       ASNENMETM           NP         InfluenzaA
# ...            ...             ...          ...                ...
# 92634  MusMusculus       SQLLNAKYL        GAP50  PlasmodiumBerghei
# 92644  MusMusculus       SQLLNAKYL        GAP50  PlasmodiumBerghei
# 92645  MusMusculus       SQLLNAKYL        GAP50  PlasmodiumBerghei
# 92646  MusMusculus       SQLLNAKYL        GAP50  PlasmodiumBerghei
# 92647  MusMusculus       SQLLNAKYL        GAP50  PlasmodiumBerghei
#
#        vdjdb.score
# 1373             3
# 1617             3
# 1619             3
# 1635             3
# 1747             3
# ...            ...
# 92634            0
# 92644            1
# 92645            1
# 92646            0
# 92647            0
#
# [2192 rows x 10 columns]

# %%
data_alpha.to_csv('data_alpha.csv')

# %%
data_alpha['antigen.epitope'].value_counts()
# Out:
# SSYRRPVGI     643
# SSLENFRAYV    430
# ASNENMETM     311
# HGIRNASFI     281
# SSPPMFRV      161
# LSLRNPILV     147
# TVYGFCLL       86
# KAVYNFATC      65
# SQLLNAKYL      62
# SIINFEKL        6
# Name: antigen.epitope, dtype: int64

# %%
import numpy as np
#alpha chain
tr_alpha = TCRrep(cell_df=data_alpha, 
                  organism='mouse', 
                  chains=['alpha'], 
                  db_file='alphabeta_gammadelta_db.tsv',
                  deduplicate=True)
tr_alpha.compute_distances()

alpha_distance_matrix = tr_alpha.pw_alpha
np.save('alpha_distance_mouse_matrix.npy', alpha_distance_matrix)
tr_alpha.pw_alpha
# Out:
# /Users/guanyingxue/anaconda3/lib/python3.11/site-packages/tcrdist/repertoire.py:159: UserWarning: cell_df needs a counts column to track clonal number of frequency
#
#   self._validate_cell_df()
# /Users/guanyingxue/anaconda3/lib/python3.11/site-packages/tcrdist/repertoire.py:791: UserWarning: No 'count' column provided; count column set to 1
#   warnings.warn("No 'count' column provided; count column set to 1")
# array([[  0,  90,  90, ..., 115, 148, 133],
#        [ 90,   0,  24, ..., 145, 133, 154],
#        [ 90,  24,   0, ..., 145, 145, 154],
#        ...,
#        [115, 145, 145, ...,   0, 115, 116],
#        [148, 133, 145, ..., 115,   0, 154],
#        [133, 154, 154, ..., 116, 154,   0]], dtype=int16)

# %%
#beta chain
from tcrdist.repertoire import TCRrep
import numpy as np
data_beta = pd.read_csv("beta.csv")
tr_beta = TCRrep(cell_df=data_beta, 
                 organism='mouse', 
                 chains=['beta'], 
                 db_file='alphabeta_gammadelta_db.tsv',
                 deduplicate=True)
tr_beta.compute_distances()
beta_distance_matrix = tr_beta.pw_beta
np.save('beta_distance_mouse_matrix.npy', beta_distance_matrix)
tr_beta.pw_beta
# Out:
# /Users/guanyingxue/anaconda3/lib/python3.11/site-packages/tcrdist/repertoire.py:159: UserWarning: cell_df needs a counts column to track clonal number of frequency
#
#   self._validate_cell_df()
# /Users/guanyingxue/anaconda3/lib/python3.11/site-packages/tcrdist/repertoire.py:791: UserWarning: No 'count' column provided; count column set to 1
#   warnings.warn("No 'count' column provided; count column set to 1")
# array([[  0, 159,  72, ...,  96,  75, 111],
#        [159,   0, 126, ..., 131, 128, 128],
#        [ 72, 126,   0, ...,  99, 111,  99],
#        ...,
#        [ 96, 131,  99, ...,   0,  45,  63],
#        [ 75, 128, 111, ...,  45,   0,  78],
#        [111, 128,  99, ...,  63,  78,   0]], dtype=int16)

# %%
import matplotlib.pyplot as plt

matrix = alpha_distance_matrix

plt.imshow(matrix, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.show()

# %%
import seaborn as sns

matrix = alpha_distance_matrix

sns.heatmap(matrix, cmap='viridis')
plt.show()

# %%
#beta chain
from tcrdist.repertoire import TCRrep
import numpy as np
data_beta = pd.read_csv("beta.csv")
tr_beta = TCRrep(cell_df=data_beta, 
                 organism='mouse', 
                 chains=['beta'], 
                 db_file='alphabeta_gammadelta_db.tsv',
                 deduplicate=True)
tr_beta.compute_distances()
beta_distance_matrix = tr_beta.pw_beta
np.save('beta_distance_mouse_matrix.npy', beta_distance_matrix)
tr_beta.pw_beta
# Out:
# /Users/guanyingxue/anaconda3/lib/python3.11/site-packages/tcrdist/repertoire.py:159: UserWarning: cell_df needs a counts column to track clonal number of frequency
#
#   self._validate_cell_df()
# /Users/guanyingxue/anaconda3/lib/python3.11/site-packages/tcrdist/repertoire.py:791: UserWarning: No 'count' column provided; count column set to 1
#   warnings.warn("No 'count' column provided; count column set to 1")
# array([[  0, 159,  72, ...,  96,  75, 111],
#        [159,   0, 126, ..., 131, 128, 128],
#        [ 72, 126,   0, ...,  99, 111,  99],
#        ...,
#        [ 96, 131,  99, ...,   0,  45,  63],
#        [ 75, 128, 111, ...,  45,   0,  78],
#        [111, 128,  99, ...,  63,  78,   0]], dtype=int16)

# %%
# Merge by complex.id, assuming that each complex.id corresponds to a pair of alpha and beta chains
# Make sure complex.id is not equal to 0
#data_alpha = data_alpha[data_alpha['complex.id'] != 0]
#data_beta = data_beta[data_beta['complex.id'] != 0]
# Merge alpha and beta chain data
#data_combined = pd.merge(data_alpha, data_beta, on='complex.id', suffixes=('_alpha', '_beta'))
#data_combined['combined_feature'] = data_combined['cdr3_a_aa'] + "_" + data_combined['cdr3_b_aa']

#data_combined.to_csv('data_combined.csv')
#data_combined

# %%
#data_combined['cdr3_b_aa'] = data_combined['combined_feature']
#tr = TCRrep(cell_df = data_combined,
#            organism = 'mouse', 
#            chains = ['beta'],  # The chains parameter is required here, but because we are using comprehensive features, it does not matter which chain is actually selected.
#            db_file='alphabeta_gammadelta_db.tsv', 
#            )
#tr.compute_distances()
#tr.pw_beta

# %%
#distance_matrix = tr.pw_beta
#np.save('combined_distance_mouse_matrix.npy', distance_matrix)
