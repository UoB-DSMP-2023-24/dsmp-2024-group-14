# %%
# ab combined 后预测homo

import pandas as pd

data=pd.read_csv('./vdjdb.txt',sep='\t', header=0)
data[data['species'] == 'HomoSapiens']
data=data[data['vdjdb.score'] != 0]
data
# Out:
#        complex.id gene                  cdr3         v.segm      j.segm  \
# 0               1  TRA         CIVRAPGRADMRF    TRAV26-1*01   TRAJ43*01
# 1               1  TRB  CASSYLPGQGDHYSNQPQHF      TRBV13*01  TRBJ1-5*01
# 2               0  TRB   CASSFEAGQGFFSNQPQHF      TRBV13*01  TRBJ1-5*01
# 3               2  TRA        CAVPSGAGSYQLTF      TRAV20*01   TRAJ28*01
# 4               2  TRB   CASSFEPGQGFYSNQPQHF      TRBV13*01  TRBJ1-5*01
# ...           ...  ...                   ...            ...         ...
# 92686       30552  TRB        CASSQGSGGNEQFF     TRBV4-3*01  TRBJ2-1*01
# 92689       30554  TRA     CAASVLYGSSNTGKLIF  TRAV29/DV5*01   TRAJ37*01
# 92690       30554  TRB      CASSIVGSGGYNEQFF      TRBV19*01  TRBJ2-1*01
# 92767       30593  TRA          CAPQGATNKLIF    TRAV12-2*01   TRAJ32*01
# 92768       30593  TRB       CASSLGAGGQETQYF     TRBV5-1*01  TRBJ2-5*01
#
#            species           mhc.a           mhc.b mhc.class antigen.epitope  \
# 0      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# 1      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# 2      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# 3      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# 4      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# ...            ...             ...             ...       ...             ...
# 92686  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII    FPQPEQPFPWQP
# 92689  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII    QLQPFPQPELPY
# 92690  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII    QLQPFPQPELPY
# 92767  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII   PQQPFPQPEQPFP
# 92768  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII   PQQPFPQPEQPFP
#
#        ... antigen.species   reference.id  \
# 0      ...           HIV-1  PMID:15596521
# 1      ...           HIV-1  PMID:15596521
# 2      ...           HIV-1  PMID:15596521
# 3      ...           HIV-1  PMID:15596521
# 4      ...           HIV-1  PMID:15596521
# ...    ...             ...            ...
# 92686  ...           Wheat  PMID:33927715
# 92689  ...           Wheat  PMID:33927715
# 92690  ...           Wheat  PMID:33927715
# 92767  ...           Wheat  PMID:33927715
# 92768  ...           Wheat  PMID:33927715
#
#                                                   method  \
# 0      {"frequency": "", "identification": "tetramer-...
# 1      {"frequency": "", "identification": "tetramer-...
# 2      {"frequency": "", "identification": "tetramer-...
# 3      {"frequency": "", "identification": "tetramer-...
# 4      {"frequency": "", "identification": "tetramer-...
# ...                                                  ...
# 92686  {"frequency": "", "identification": "tetramer-...
# 92689  {"frequency": "", "identification": "tetramer-...
# 92690  {"frequency": "", "identification": "tetramer-...
# 92767  {"frequency": "", "identification": "tetramer-...
# 92768  {"frequency": "", "identification": "tetramer-...
#
#                                                     meta  \
# 0      {"cell.subset": "CD8+", "clone.id": "", "donor...
# 1      {"cell.subset": "CD8+", "clone.id": "", "donor...
# 2      {"cell.subset": "CD8+", "clone.id": "", "donor...
# 3      {"cell.subset": "CD8+", "clone.id": "", "donor...
# 4      {"cell.subset": "CD8+", "clone.id": "", "donor...
# ...                                                  ...
# 92686  {"cell.subset": "CD4+", "clone.id": "", "donor...
# 92689  {"cell.subset": "CD4+", "clone.id": "", "donor...
# 92690  {"cell.subset": "CD4+", "clone.id": "", "donor...
# 92767  {"cell.subset": "CD4+", "clone.id": "", "donor...
# 92768  {"cell.subset": "CD4+", "clone.id": "", "donor...
#
#                                                  cdr3fix vdjdb.score  \
# 0      {"cdr3": "CIVRAPGRADMRF", "cdr3_old": "CIVRAPG...           2
# 1      {"cdr3": "CASSYLPGQGDHYSNQPQHF", "cdr3_old": "...           2
# 2      {"cdr3": "CASSFEAGQGFFSNQPQHF", "cdr3_old": "C...           2
# 3      {"cdr3": "CAVPSGAGSYQLTF", "cdr3_old": "CAVPSG...           2
# 4      {"cdr3": "CASSFEPGQGFYSNQPQHF", "cdr3_old": "C...           2
# ...                                                  ...         ...
# 92686  {"cdr3": "CASSQGSGGNEQFF", "cdr3_old": "CASSQG...           2
# 92689  {"cdr3": "CAASVLYGSSNTGKLIF", "cdr3_old": "CAA...           2
# 92690  {"cdr3": "CASSIVGSGGYNEQFF", "cdr3_old": "CASS...           2
# 92767  {"cdr3": "CAPQGATNKLIF", "cdr3_old": "CAPQGATN...           2
# 92768  {"cdr3": "CASSLGAGGQETQYF", "cdr3_old": "CASSL...           2
#
#        web.method web.method.seq web.cdr3fix.nc web.cdr3fix.unmp
# 0            sort         sanger             no               no
# 1            sort         sanger             no               no
# 2            sort         sanger             no               no
# 3            sort         sanger             no               no
# 4            sort         sanger             no               no
# ...           ...            ...            ...              ...
# 92686        sort     singlecell             no               no
# 92689        sort     singlecell             no               no
# 92690        sort     singlecell             no               no
# 92767        sort     singlecell             no               no
# 92768        sort     singlecell             no               no
#
# [12414 rows x 21 columns]

# %%
columns_to_drop = ['antigen.species','antigen.gene','reference.id', 'method', 'meta','cdr3fix','web.method','web.method.seq','web.cdr3fix.nc','web.cdr3fix.unmp','mhc.a','mhc.b','mhc.class']
data.drop(columns=columns_to_drop, inplace=True)
df=data.dropna()
# # Filter data for alpha chain and beta chain
data_alpha = df[df['gene'] == 'TRA'].copy()
data_beta = df[df['gene'] == 'TRB'].copy()
data_alpha.to_csv('human_alpha.csv')
data_beta.to_csv('human_beta.csv')

data_alpha = data_alpha[data_alpha['complex.id'] != 0]
data_beta = data_beta[data_beta['complex.id'] != 0]

data_combined = pd.merge(data_alpha,data_beta, on='complex.id' )
data_beta.to_csv('human_combined.csv')
data_combined
# Out:
#       complex.id gene_x             cdr3_x         v.segm_x   j.segm_x  \
# 0              1    TRA      CIVRAPGRADMRF      TRAV26-1*01  TRAJ43*01
# 1              2    TRA     CAVPSGAGSYQLTF        TRAV20*01  TRAJ28*01
# 2              4    TRA      CAYRPPGTYKYIF  TRAV38-2/DV8*01  TRAJ40*01
# 3              5    TRA      CIVRAPGRADMRF      TRAV26-1*01  TRAJ43*01
# 4              6    TRA     CAVPSGAGSYQLTF        TRAV20*01  TRAJ28*01
# ...          ...    ...                ...              ...        ...
# 1863       30550    TRA         CIALNARLMF      TRAV26-1*01  TRAJ31*01
# 1864       30551    TRA   CAMREGRYSSASKIIF    TRAV14/DV4*01   TRAJ3*01
# 1865       30552    TRA   CLVGDGDGGATNKLIF         TRAV4*01  TRAJ32*01
# 1866       30554    TRA  CAASVLYGSSNTGKLIF    TRAV29/DV5*01  TRAJ37*01
# 1867       30593    TRA       CAPQGATNKLIF      TRAV12-2*01  TRAJ32*01
#
#         species_x antigen.epitope_x  vdjdb.score_x gene_y  \
# 0     HomoSapiens          FLKEKGGL              2    TRB
# 1     HomoSapiens          FLKEKGGL              2    TRB
# 2     HomoSapiens          FLKEKGGL              2    TRB
# 3     HomoSapiens          FLKEQGGL              2    TRB
# 4     HomoSapiens          FLKEQGGL              2    TRB
# ...           ...               ...            ...    ...
# 1863  HomoSapiens      PQPELPYPQPQL              2    TRB
# 1864  HomoSapiens      FPQPEQPFPWQP              2    TRB
# 1865  HomoSapiens      FPQPEQPFPWQP              2    TRB
# 1866  HomoSapiens      QLQPFPQPELPY              2    TRB
# 1867  HomoSapiens     PQQPFPQPEQPFP              2    TRB
#
#                     cdr3_y    v.segm_y    j.segm_y    species_y  \
# 0     CASSYLPGQGDHYSNQPQHF   TRBV13*01  TRBJ1-5*01  HomoSapiens
# 1      CASSFEPGQGFYSNQPQHF   TRBV13*01  TRBJ1-5*01  HomoSapiens
# 2           CASSALASLNEQFF   TRBV14*01  TRBJ2-1*01  HomoSapiens
# 3     CASSYLPGQGDHYSNQPQHF   TRBV13*01  TRBJ1-5*01  HomoSapiens
# 4      CASSFEPGQGFYSNQPQHF   TRBV13*01  TRBJ1-5*01  HomoSapiens
# ...                    ...         ...         ...          ...
# 1863         CASSLRATDTQYF  TRBV7-2*01  TRBJ2-3*01  HomoSapiens
# 1864       CATSRAGGGGEKLFF   TRBV15*01  TRBJ1-4*01  HomoSapiens
# 1865        CASSQGSGGNEQFF  TRBV4-3*01  TRBJ2-1*01  HomoSapiens
# 1866      CASSIVGSGGYNEQFF   TRBV19*01  TRBJ2-1*01  HomoSapiens
# 1867       CASSLGAGGQETQYF  TRBV5-1*01  TRBJ2-5*01  HomoSapiens
#
#      antigen.epitope_y  vdjdb.score_y
# 0             FLKEKGGL              2
# 1             FLKEKGGL              2
# 2             FLKEKGGL              2
# 3             FLKEQGGL              2
# 4             FLKEQGGL              2
# ...                ...            ...
# 1863      PQPELPYPQPQL              2
# 1864      FPQPEQPFPWQP              2
# 1865      FPQPEQPFPWQP              2
# 1866      QLQPFPQPELPY              2
# 1867     PQQPFPQPEQPFP              2
#
# [1868 rows x 15 columns]

# %%
class_counts = data_combined['antigen.epitope_x'].value_counts()

# Find classes that have only one instance
single_classes = class_counts[class_counts == 1].index
data_combined = data_combined[~data_combined['antigen.epitope_x'].isin(single_classes)]

# 首先，根据`cdr3_a_aa`、`v_a_gene`和`j_a_gene`来计算距离矩阵
# 计算距离矩阵的具体代码将根据所选算法和数据类型有所不同

# 定义特征列和目标列
feature_columns = ['cdr3_x', 'cdr3_y', 'v.segm_x', 'j.segm_x', 'v.segm_y', 'j.segm_y' ]
target_column = 'antigen.epitope_x'

# 提取特征和目标
X = data_combined[feature_columns]  # 或是距离矩阵，取决于您的模型需求
y = data_combined[target_column]

# %%
column_trans = ColumnTransformer(
    [
        ('one_hot_encoder_vj', OneHotEncoder(), ['v.segm_x', 'j.segm_x', 'v.segm_y', 'j.segm_y']),
        ('one_hot_encoder_cdr3', OneHotEncoder(handle_unknown='ignore'), ['cdr3_x', 'cdr3_y'])
    ],
    remainder='drop'
)

X_encoded = column_trans.fit_transform(data_combined)
# 分层划分测试集和训练集
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, stratify=y, random_state=42)

# %%
# 5. 计算类别权重
from sklearn.utils.class_weight import compute_class_weight
class_weights = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
weights = dict(zip(np.unique(y_train), class_weights))
#*
# 6. 训练随机森林模型
rf_classifier_weighted = RandomForestClassifier(random_state=30, class_weight=weights)
rf_classifier_weighted.fit(X_train, y_train)

# 7. 进行预测
y_pred_weighted = rf_classifier_weighted.predict(X_test)

# 8. 生成和显示分类报告
classification_report_weighted = classification_report(y_test, y_pred_weighted, zero_division=0)
print(classification_report_weighted)

# 9. 计算和显示准确率、精确度、召回率和F1分数
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
accuracy = accuracy_score(y_test, y_pred_weighted)
precision = precision_score(y_test, y_pred_weighted, average='macro', zero_division=0)
recall = recall_score(y_test, y_pred_weighted, average='macro', zero_division=0)
f1 = f1_score(y_test, y_pred_weighted, average='macro', zero_division=0)

print(f'Accuracy: {accuracy:.2f}')
print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')
print(f'F1 Score: {f1:.2f}')
#onehot编码，随机过采样补全，随机森林预测
# Out:
#                        precision    recall  f1-score   support
#
#             AAFKRSCLK       0.00      0.00      0.00         1
#             AAGIGILTV       0.50      1.00      0.67         2
#            ALDPHSGHFV       1.00      1.00      1.00         1
#             ALLPGLPAA       0.00      0.00      0.00         1
#             ALSPVIPHI       1.00      1.00      1.00         2
#             ALWGFFPVL       1.00      1.00      1.00         1
#             ALYGFVPVL       0.00      0.00      0.00         1
#           APARLERRHSA       0.00      0.00      0.00         1
#         APQPELPYPQPGS       0.00      0.00      0.00         0
#         APRGPHGGAASGL       1.00      1.00      1.00         2
#             CINGVCWTV       1.00      0.25      0.40         4
#             CVNGSCFTV       0.00      0.00      0.00         3
#          DATYQRTRALVR       1.00      0.25      0.40         4
#        DFHFEVFNFVPCSI       1.00      0.50      0.67         2
#         DPPALASTNAEVT       0.00      0.00      0.00         2
#            EAAGIGILTV       0.00      0.00      0.00         3
#            ELAGIGILTV       0.50      0.20      0.29         5
#           EPLPQGQLTAY       1.00      0.33      0.50         3
#             FAMQMAYRF       0.00      0.00      0.00         1
#             FLIYLDVSV       0.00      0.00      0.00         1
#              FLKEKGGL       0.00      0.00      0.00         1
#              FLKEQGGL       0.00      0.00      0.00         0
#             FLRGRAYGL       1.00      1.00      1.00         2
# FNNFTVSFWLRVPKVSASHLE       0.00      0.00      0.00         1
#          FPQPEQPFPWQP       0.00      0.00      0.00         1
#            GADGVGKSAL       0.00      0.00      0.00         1
#       GDFGLATEKSRWSGS       0.00      0.00      0.00         1
#             GILGFVFTL       0.85      0.82      0.83        49
#             GLCTLVAML       1.00      0.93      0.96        14
#             GPRLGVRAT       0.00      0.00      0.00         2
#     GQVELGGGNAVEVCKGS       0.00      0.00      0.00         1
#            GTSGSPIINR       0.00      0.00      0.00         1
#            GTSGSPIVNR       0.00      0.00      0.00         1
#             GVYALIAGA       0.00      0.00      0.00         1
#             HMTEVVRHC       1.00      1.00      1.00         2
#           HPVGEADYFEY       0.00      0.00      0.00         1
#             IPLTEEAEL       1.00      1.00      1.00         1
#             IPSINVHHY       0.00      0.00      0.00         1
#             IVTDFSVIK       0.00      0.00      0.00         1
#             KASEKIFYV       0.00      0.00      0.00         1
#            KLFEFLVYGV       1.00      1.00      1.00         1
#            KLSALGINAV       0.00      0.00      0.00         1
#            KLVALGINAV       1.00      0.43      0.60         7
#            KLVAMGINAV       0.00      0.00      0.00         1
#            KLYGLDWAEL       1.00      1.00      1.00         2
#         LLEFYLAMPFATP       0.00      0.00      0.00         3
#              LLFGPVYV       0.50      1.00      0.67         1
#             LLFGYPVYV       0.00      0.00      0.00         1
#         LPEPLPQGQLTAY       1.00      1.00      1.00         2
#       LTDEQRAAALEKAAA       1.00      1.00      1.00         1
#       MHVSFVMAYPEMLAA       0.00      0.00      0.00         1
#             MLAKALRKV       0.00      0.00      0.00         1
#             NLNCCSVPV       0.00      0.00      0.00         1
#             NLVPMVATV       0.45      0.97      0.62        88
#             NYNYLYRLF       0.00      0.00      0.00         2
#             PFPQPELPY       0.00      0.00      0.00         3
#       PGVLLKEFTVSGNIL       1.00      0.50      0.67         2
#         PKYVKQNTLKLAT       0.50      1.00      0.67         1
#             PQPELPYPQ       0.00      0.00      0.00         1
#           PQPELPYPQPE       0.00      0.00      0.00         2
#          PQPELPYPQPQL       0.00      0.00      0.00         1
#         PQQPFPQPEQPFP       0.00      0.00      0.00         1
#       PSPSMGRDIKVQFQS       0.00      0.00      0.00         1
#          QLQPFPQPELPY       0.00      0.00      0.00         2
#             QYIKWPWYI       0.00      0.00      0.00        10
#              RAKFKQLL       1.00      1.00      1.00         1
#             RAQAPPPSW       0.00      0.00      0.00         1
#         RFYKTLRAEQASQ       1.00      1.00      1.00         1
#             RLARLALVL       0.50      0.50      0.50         2
#             RLGPVQNEV       0.00      0.00      0.00         1
#            RLITGRLQSL       1.00      0.50      0.67         2
#             RLPGVLPRA       0.00      0.00      0.00         3
#             RMFPNAPYL       0.00      0.00      0.00         1
#             RPRGEVRFL       0.80      0.80      0.80         5
#            RYPLTFGWCF       0.00      0.00      0.00         1
#             SLLMWITQC       0.67      1.00      0.80         2
#             SLLMWITQV       0.00      0.00      0.00         1
#             SPRWYFYYL       0.00      0.00      0.00         4
#            SSCMGGMNWR       0.00      0.00      0.00         1
#       STRQALRPRADGPVG       0.50      1.00      0.67         1
#           SVCAGILSYGV       0.00      0.00      0.00         1
#       TAAQAAVVRFQEAAN       1.00      1.00      1.00         1
#              TAFTIPSI       0.50      0.33      0.40         3
#        TFEYVSQPFLMDLE       0.85      0.94      0.89        18
#             TLWCSPIKV       0.00      0.00      0.00         2
#            TPRVTGGGAM       1.00      0.50      0.67         2
#             VAANIVLTV       0.00      0.00      0.00         3
#             VVMSWAPPV       0.00      0.00      0.00         2
#            VVVGAVGVGK       1.00      1.00      1.00         1
#               YHSIEWA       0.00      0.00      0.00         1
#             YLEPGPVTA       0.00      0.00      0.00         1
#             YLQPRTFLL       1.00      0.31      0.47        13
#
#              accuracy                           0.61       335
#             macro avg       0.35      0.32      0.31       335
#          weighted avg       0.55      0.61      0.53       335
#
# Accuracy: 0.61
# Precision: 0.35
# Recall: 0.32
# F1 Score: 0.31

# %%
results_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_weighted})

mismatches = results_df[results_df['Actual'] != results_df['Predicted']]

# 统计每个实际类别预测错误的数量
error_counts = mismatches['Actual'].value_counts()
print("Error Counts by Actual Category:")
print(error_counts)
# Out:
# Error Counts by Actual Category:
# QYIKWPWYI            10
# YLQPRTFLL             9
# GILGFVFTL             9
# SPRWYFYYL             4
# ELAGIGILTV            4
#                      ..
# SVCAGILSYGV           1
# GQVELGGGNAVEVCKGS     1
# GLCTLVAML             1
# GTSGSPIVNR            1
# GVYALIAGA             1
# Name: Actual, Length: 70, dtype: int64
