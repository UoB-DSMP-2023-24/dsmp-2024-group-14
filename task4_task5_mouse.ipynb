# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# Load distance matrix
distance_matrix = np.load('alpha_distance_mouse_matrix.npy')

# Load the dataset containing sequence features
data = pd.read_csv("data_alpha.csv")

# Extract sequence features (antigen.epitope)
sequences = data['antigen.epitope']

# Assuming you have a column named 'category' in your DataFrame containing category labels
categories = data['antigen.epitope']

# Perform dimensionality reduction using t-SNE
tsne = TSNE(n_components=2, metric='precomputed')
embeddings = tsne.fit_transform(distance_matrix)

# Get unique categories
unique_categories = np.unique(categories)

# Plot the embeddings with different colors for different categories
plt.figure(figsize=(8, 6))
for category in unique_categories:
    indices = (categories == category)
    plt.scatter(embeddings[indices, 0], embeddings[indices, 1], label=category, s=10)

plt.title('t-SNE Embedding of Sequence Features')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))  # Place legend on the right
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:819: FutureWarning: 'square_distances' has been introduced in 0.24 to help phase out legacy squaring behavior. The 'legacy' setting will be removed in 1.1 (renaming of 0.26), and the default setting will be changed to True. In 1.3, 'square_distances' will be removed altogether, and distances will be squared by default. Set 'square_distances'=True to silence this warning.
#   warnings.warn(

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# Load distance matrix
distance_matrix = np.load('alpha_distance_mouse_matrix.npy')

# Load the dataset containing sequence features
data = pd.read_csv("data_alpha.csv")

# Extract sequence features (antigen.epitope)
sequences = data['antigen.species']

# Assuming you have a column named 'category' in your DataFrame containing category labels
categories = data['antigen.species']

# Perform dimensionality reduction using t-SNE
tsne = TSNE(n_components=2, metric='precomputed')
embeddings1 = tsne.fit_transform(distance_matrix)

# Get unique categories
unique_categories = np.unique(categories)

# Plot the embeddings with different colors for different categories
plt.figure(figsize=(8, 6))
for category in unique_categories:
    indices = (categories == category)
    plt.scatter(embeddings[indices, 0], embeddings[indices, 1], label=category, s=10)

plt.title('t-SNE Embedding of Sequence Features')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))  # Place legend on the right
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:819: FutureWarning: 'square_distances' has been introduced in 0.24 to help phase out legacy squaring behavior. The 'legacy' setting will be removed in 1.1 (renaming of 0.26), and the default setting will be changed to True. In 1.3, 'square_distances' will be removed altogether, and distances will be squared by default. Set 'square_distances'=True to silence this warning.
#   warnings.warn(

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import umap

# Load distance matrix
distance_matrix = np.load('alpha_distance_mouse_matrix.npy')

# Load the dataset containing sequence features
data = pd.read_csv("data_alpha.csv")

# Extract sequence features (antigen.epitope)
sequences = data['antigen.species']

# Assuming you have a column named 'category' in your DataFrame containing category labels
categories = data['antigen.species']

# Perform dimensionality reduction using UMAP
reducer = umap.UMAP(n_components=2, metric='precomputed')
embeddings = reducer.fit_transform(distance_matrix)

# Get unique categories
unique_categories = np.unique(categories)

# Plot the embeddings with different colors for different categories
plt.figure(figsize=(8, 6))
for category in unique_categories:
    indices = (categories == category)
    plt.scatter(embeddings[indices, 0], embeddings[indices, 1], label=category, s=10)

plt.title('UMAP Embedding of Sequence Features')
plt.xlabel('UMAP Component 1')
plt.ylabel('UMAP Component 2')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))  # Place legend on the right
plt.show()
# Out:
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\umap\umap_.py:1857: UserWarning: using precomputed metric; inverse_transform will be unavailable
#   warn("using precomputed metric; inverse_transform will be unavailable")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Load distance matrix
distance_matrix = np.load('alpha_distance_mouse_matrix.npy')

# Load the dataset containing sequence features
data = pd.read_csv("data_alpha.csv")

# Extract sequence features (antigen.species)
sequences = data['antigen.species']

# Assuming you have a column named 'category' in your DataFrame containing category labels
categories = data['antigen.species']

# Perform dimensionality reduction using PCA
pca = PCA(n_components=2)
embeddings = pca.fit_transform(distance_matrix)

# Get unique categories
unique_categories = np.unique(categories)

# Plot the embeddings with different colors for different categories
plt.figure(figsize=(8, 6))
for category in unique_categories:
    indices = (categories == category)
    plt.scatter(embeddings[indices, 0], embeddings[indices, 1], label=category, s=10)

plt.title('PCA Embedding of Sequence Features')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))  # Place legend on the right
plt.show()

# %%
data
# Out:
#      Unnamed: 0  complex.id gene         cdr3_a_aa     v_a_gene   j_a_gene  \
# 0          1271         106  TRA  CAMRGDYGGSGNKLIF    TRAV16*01  TRAJ32*01
# 1          1275         108  TRA      CAVSGFASALTF   TRAV9-4*01  TRAJ35*01
# 2          1279         110  TRA     CAARYQGGRALIF  TRAV14-1*01  TRAJ15*01
# 3          1283         112  TRA      CAVSGFASALTF   TRAV9-4*01  TRAJ35*01
# 4          1285         113  TRA  CAMRGDYGGSGNKLIF    TRAV16*01  TRAJ32*01
# ..          ...         ...  ...               ...          ...        ...
# 919       92617           0  TRA  CATDHMQQGTGSKLSF   TRAV8-2*01  TRAJ58*01
# 920       92618           0  TRA    CVLTNTEGADRLTF  TRAV13-5*01  TRAJ45*01
# 921       92619           0  TRA      CATPGGNYKPTF  TRAV8D-2*01   TRAJ6*01
# 922       92644           0  TRA     CAARGYNQGKLIF  TRAV14-2*01  TRAJ23*01
# 923       92645           0  TRA     CATSDTNAYKVIF   TRAV8-2*01  TRAJ30*01
#
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0         0
# complex.id         0
# gene               0
# cdr3_a_aa          0
# v_a_gene           0
# j_a_gene           0
# species            0
# antigen.epitope    0
# antigen.gene       0
# antigen.species    0
# vdjdb.score        0
# dtype: int64
