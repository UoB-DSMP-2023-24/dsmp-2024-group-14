# %%
import pandas as pd
pd.set_option('display.max_columns', None)
data=pd.read_csv('./vdjdb.txt',sep='\t', header=0)

data
# Out:
#        complex.id gene                  cdr3       v.segm      j.segm  \
# 0               1  TRA         CIVRAPGRADMRF  TRAV26-1*01   TRAJ43*01
# 1               1  TRB  CASSYLPGQGDHYSNQPQHF    TRBV13*01  TRBJ1-5*01
# 2               0  TRB   CASSFEAGQGFFSNQPQHF    TRBV13*01  TRBJ1-5*01
# 3               2  TRA        CAVPSGAGSYQLTF    TRAV20*01   TRAJ28*01
# 4               2  TRB   CASSFEPGQGFYSNQPQHF    TRBV13*01  TRBJ1-5*01
# ...           ...  ...                   ...          ...         ...
# 92766       30592  TRB       CASSPGQGGDNEQFF   TRBV7-3*01  TRBJ2-1*01
# 92767       30593  TRA          CAPQGATNKLIF  TRAV12-2*01   TRAJ32*01
# 92768       30593  TRB       CASSLGAGGQETQYF   TRBV5-1*01  TRBJ2-5*01
# 92769       30594  TRA        CLVGGSGGYNKLIF     TRAV4*01    TRAJ4*01
# 92770       30594  TRB         CASSSTAQETQYF  TRBV11-2*01  TRBJ2-5*01
#
#            species           mhc.a           mhc.b mhc.class antigen.epitope  \
# 0      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# 1      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# 2      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# 3      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# 4      HomoSapiens        HLA-B*08             B2M      MHCI        FLKEKGGL
# ...            ...             ...             ...       ...             ...
# 92766  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII   PQQPFPQPEQPFP
# 92767  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII   PQQPFPQPEQPFP
# 92768  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII   PQQPFPQPEQPFP
# 92769  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII   PQQPFPQPEQPFP
# 92770  HomoSapiens  HLA-DQA1*05:01  HLA-DQB1*02:01     MHCII   PQQPFPQPEQPFP
#
#       antigen.gene antigen.species   reference.id  \
# 0              Nef           HIV-1  PMID:15596521
# 1              Nef           HIV-1  PMID:15596521
# 2              Nef           HIV-1  PMID:15596521
# 3              Nef           HIV-1  PMID:15596521
# 4              Nef           HIV-1  PMID:15596521
# ...            ...             ...            ...
# 92766       Gluten           Wheat  PMID:33927715
# 92767       Gluten           Wheat  PMID:33927715
# 92768       Gluten           Wheat  PMID:33927715
# 92769       Gluten           Wheat  PMID:33927715
# 92770       Gluten           Wheat  PMID:33927715
#
#                                                   method  \
# 0      {"frequency": "", "identification": "tetramer-...
# 1      {"frequency": "", "identification": "tetramer-...
# 2      {"frequency": "", "identification": "tetramer-...
# 3      {"frequency": "", "identification": "tetramer-...
# 4      {"frequency": "", "identification": "tetramer-...
# ...                                                  ...
# 92766  {"frequency": "", "identification": "tetramer-...
# 92767  {"frequency": "", "identification": "tetramer-...
# 92768  {"frequency": "", "identification": "tetramer-...
# 92769  {"frequency": "", "identification": "tetramer-...
# 92770  {"frequency": "", "identification": "tetramer-...
#
#                                                     meta  \
# 0      {"cell.subset": "CD8+", "clone.id": "", "donor...
# 1      {"cell.subset": "CD8+", "clone.id": "", "donor...
# 2      {"cell.subset": "CD8+", "clone.id": "", "donor...
# 3      {"cell.subset": "CD8+", "clone.id": "", "donor...
# 4      {"cell.subset": "CD8+", "clone.id": "", "donor...
# ...                                                  ...
# 92766  {"cell.subset": "CD4+", "clone.id": "", "donor...
# 92767  {"cell.subset": "CD4+", "clone.id": "", "donor...
# 92768  {"cell.subset": "CD4+", "clone.id": "", "donor...
# 92769  {"cell.subset": "CD4+", "clone.id": "", "donor...
# 92770  {"cell.subset": "CD4+", "clone.id": "", "donor...
#
#                                                  cdr3fix  vdjdb.score  \
# 0      {"cdr3": "CIVRAPGRADMRF", "cdr3_old": "CIVRAPG...            2
# 1      {"cdr3": "CASSYLPGQGDHYSNQPQHF", "cdr3_old": "...            2
# 2      {"cdr3": "CASSFEAGQGFFSNQPQHF", "cdr3_old": "C...            2
# 3      {"cdr3": "CAVPSGAGSYQLTF", "cdr3_old": "CAVPSG...            2
# 4      {"cdr3": "CASSFEPGQGFYSNQPQHF", "cdr3_old": "C...            2
# ...                                                  ...          ...
# 92766  {"cdr3": "CASSPGQGGDNEQFF", "cdr3_old": "CASSP...            0
# 92767  {"cdr3": "CAPQGATNKLIF", "cdr3_old": "CAPQGATN...            2
# 92768  {"cdr3": "CASSLGAGGQETQYF", "cdr3_old": "CASSL...            2
# 92769  {"cdr3": "CLVGGSGGYNKLIF", "cdr3_old": "CLVGGS...            0
# 92770  {"cdr3": "CASSSTAQETQYF", "cdr3_old": "CASSSTA...            0
#
#       web.method web.method.seq web.cdr3fix.nc web.cdr3fix.unmp
# 0           sort         sanger             no               no
# 1           sort         sanger             no               no
# 2           sort         sanger             no               no
# 3           sort         sanger             no               no
# 4           sort         sanger             no               no
# ...          ...            ...            ...              ...
# 92766       sort     singlecell             no               no
# 92767       sort     singlecell             no               no
# 92768       sort     singlecell             no               no
# 92769       sort     singlecell             no               no
# 92770       sort     singlecell             no               no
#
# [92771 rows x 21 columns]

# %%
columns_to_drop = ['reference.id', 'method', 'meta','cdr3fix','web.method','web.method.seq','web.cdr3fix.nc','web.cdr3fix.unmp','mhc.a','mhc.b','mhc.class']
data.drop(columns=columns_to_drop, inplace=True)
data
# Out:
#        complex.id gene                  cdr3       v.segm      j.segm  \
# 0               1  TRA         CIVRAPGRADMRF  TRAV26-1*01   TRAJ43*01
# 1               1  TRB  CASSYLPGQGDHYSNQPQHF    TRBV13*01  TRBJ1-5*01
# 2               0  TRB   CASSFEAGQGFFSNQPQHF    TRBV13*01  TRBJ1-5*01
# 3               2  TRA        CAVPSGAGSYQLTF    TRAV20*01   TRAJ28*01
# 4               2  TRB   CASSFEPGQGFYSNQPQHF    TRBV13*01  TRBJ1-5*01
# ...           ...  ...                   ...          ...         ...
# 92766       30592  TRB       CASSPGQGGDNEQFF   TRBV7-3*01  TRBJ2-1*01
# 92767       30593  TRA          CAPQGATNKLIF  TRAV12-2*01   TRAJ32*01
# 92768       30593  TRB       CASSLGAGGQETQYF   TRBV5-1*01  TRBJ2-5*01
# 92769       30594  TRA        CLVGGSGGYNKLIF     TRAV4*01    TRAJ4*01
# 92770       30594  TRB         CASSSTAQETQYF  TRBV11-2*01  TRBJ2-5*01
#
#            species antigen.epitope antigen.gene antigen.species  vdjdb.score
# 0      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# 1      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# 2      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# 3      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# 4      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# ...            ...             ...          ...             ...          ...
# 92766  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            0
# 92767  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            2
# 92768  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            2
# 92769  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            0
# 92770  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            0
#
# [92771 rows x 10 columns]

# %%
data.isnull().sum()
# Out:
# complex.id            0
# gene                  0
# cdr3                  0
# v.segm              101
# j.segm             1145
# species               0
# antigen.epitope       0
# antigen.gene         62
# antigen.species       0
# vdjdb.score           0
# dtype: int64

# %%
data = data.dropna() # dropping rows with any column having null values

# %%
data
# Out:
#        complex.id gene                  cdr3       v.segm      j.segm  \
# 0               1  TRA         CIVRAPGRADMRF  TRAV26-1*01   TRAJ43*01
# 1               1  TRB  CASSYLPGQGDHYSNQPQHF    TRBV13*01  TRBJ1-5*01
# 2               0  TRB   CASSFEAGQGFFSNQPQHF    TRBV13*01  TRBJ1-5*01
# 3               2  TRA        CAVPSGAGSYQLTF    TRAV20*01   TRAJ28*01
# 4               2  TRB   CASSFEPGQGFYSNQPQHF    TRBV13*01  TRBJ1-5*01
# ...           ...  ...                   ...          ...         ...
# 92766       30592  TRB       CASSPGQGGDNEQFF   TRBV7-3*01  TRBJ2-1*01
# 92767       30593  TRA          CAPQGATNKLIF  TRAV12-2*01   TRAJ32*01
# 92768       30593  TRB       CASSLGAGGQETQYF   TRBV5-1*01  TRBJ2-5*01
# 92769       30594  TRA        CLVGGSGGYNKLIF     TRAV4*01    TRAJ4*01
# 92770       30594  TRB         CASSSTAQETQYF  TRBV11-2*01  TRBJ2-5*01
#
#            species antigen.epitope antigen.gene antigen.species  vdjdb.score
# 0      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# 1      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# 2      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# 3      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# 4      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# ...            ...             ...          ...             ...          ...
# 92766  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            0
# 92767  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            2
# 92768  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            2
# 92769  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            0
# 92770  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            0
#
# [91550 rows x 10 columns]

# %%
data['species'].value_counts()
# Out:
# HomoSapiens      84271
# MusMusculus       5247
# MacacaMulatta     2032
# Name: species, dtype: int64

# %%
# Filter by species
data_people = data[data['species'] == 'HomoSapiens'] 
#next analysis is for mouse only
df=data_people
df
# Out:
#        complex.id gene                  cdr3       v.segm      j.segm  \
# 0               1  TRA         CIVRAPGRADMRF  TRAV26-1*01   TRAJ43*01
# 1               1  TRB  CASSYLPGQGDHYSNQPQHF    TRBV13*01  TRBJ1-5*01
# 2               0  TRB   CASSFEAGQGFFSNQPQHF    TRBV13*01  TRBJ1-5*01
# 3               2  TRA        CAVPSGAGSYQLTF    TRAV20*01   TRAJ28*01
# 4               2  TRB   CASSFEPGQGFYSNQPQHF    TRBV13*01  TRBJ1-5*01
# ...           ...  ...                   ...          ...         ...
# 92766       30592  TRB       CASSPGQGGDNEQFF   TRBV7-3*01  TRBJ2-1*01
# 92767       30593  TRA          CAPQGATNKLIF  TRAV12-2*01   TRAJ32*01
# 92768       30593  TRB       CASSLGAGGQETQYF   TRBV5-1*01  TRBJ2-5*01
# 92769       30594  TRA        CLVGGSGGYNKLIF     TRAV4*01    TRAJ4*01
# 92770       30594  TRB         CASSSTAQETQYF  TRBV11-2*01  TRBJ2-5*01
#
#            species antigen.epitope antigen.gene antigen.species  vdjdb.score
# 0      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# 1      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# 2      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# 3      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# 4      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# ...            ...             ...          ...             ...          ...
# 92766  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            0
# 92767  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            2
# 92768  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            2
# 92769  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            0
# 92770  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            0
#
# [84271 rows x 10 columns]

# %%
df['antigen.epitope'].value_counts()
# Out:
# KLGGALQAK     27669
# GILGFVFTL      9948
# NLVPMVATV      7916
# AVFDRKSDAK     3512
# RAKFKQLL       2747
#               ...
# IPIQASLSF         1
# TLVPQEHYV         1
# SLPFGWLIV         1
# LYDANYFLC         1
# STDTVVEHV         1
# Name: antigen.epitope, Length: 1096, dtype: int64

# %%
from tcrdist.repertoire import TCRrep
import pandas as pd
# 针对alpha链和beta链的数据进行筛选
data_alpha = df[df['gene'] == 'TRA'].copy()
data_beta = df[df['gene'] == 'TRB'].copy()
# 将数据列重命名以匹配TCRrep的期望格式
data_alpha.rename(columns={'cdr3': 'cdr3_a_aa', 'v.segm': 'v_a_gene', 'j.segm': 'j_a_gene'}, inplace=True)
data_beta.rename(columns={'cdr3': 'cdr3_b_aa', 'v.segm': 'v_b_gene', 'j.segm': 'j_b_gene'}, inplace=True)
data_beta
# Out:
#        complex.id gene             cdr3_b_aa     v_b_gene    j_b_gene  \
# 1               1  TRB  CASSYLPGQGDHYSNQPQHF    TRBV13*01  TRBJ1-5*01
# 2               0  TRB   CASSFEAGQGFFSNQPQHF    TRBV13*01  TRBJ1-5*01
# 4               2  TRB   CASSFEPGQGFYSNQPQHF    TRBV13*01  TRBJ1-5*01
# 6               3  TRB  CASSYEPGQVSHYSNQPQHF    TRBV13*01  TRBJ1-5*01
# 8               4  TRB        CASSALASLNEQFF    TRBV14*01  TRBJ2-1*01
# ...           ...  ...                   ...          ...         ...
# 92762       30590  TRB         CASSVRSTDTQYF   TRBV7-2*01  TRBJ2-3*01
# 92764       30591  TRB         CASSLRYTDTQYF   TRBV7-2*01  TRBJ2-3*01
# 92766       30592  TRB       CASSPGQGGDNEQFF   TRBV7-3*01  TRBJ2-1*01
# 92768       30593  TRB       CASSLGAGGQETQYF   TRBV5-1*01  TRBJ2-5*01
# 92770       30594  TRB         CASSSTAQETQYF  TRBV11-2*01  TRBJ2-5*01
#
#            species antigen.epitope antigen.gene antigen.species  vdjdb.score
# 1      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# 2      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# 4      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# 6      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# 8      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# ...            ...             ...          ...             ...          ...
# 92762  HomoSapiens    PQPELPYPQPQL       Gluten           Wheat            0
# 92764  HomoSapiens    PQPELPYPQPQL       Gluten           Wheat            0
# 92766  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            0
# 92768  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            2
# 92770  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            0
#
# [49549 rows x 10 columns]

# %%
data_alpha
# Out:
#        complex.id gene       cdr3_a_aa         v_a_gene   j_a_gene  \
# 0               1  TRA   CIVRAPGRADMRF      TRAV26-1*01  TRAJ43*01
# 3               2  TRA  CAVPSGAGSYQLTF        TRAV20*01  TRAJ28*01
# 7               4  TRA   CAYRPPGTYKYIF  TRAV38-2/DV8*01  TRAJ40*01
# 9               5  TRA   CIVRAPGRADMRF      TRAV26-1*01  TRAJ43*01
# 12              6  TRA  CAVPSGAGSYQLTF        TRAV20*01  TRAJ28*01
# ...           ...  ...             ...              ...        ...
# 92761       30590  TRA   CMDEGGSNYKLTF      TRAV26-1*01  TRAJ53*01
# 92763       30591  TRA     CSLYNNNDMRF      TRAV26-1*01  TRAJ43*01
# 92765       30592  TRA   CALSTDSWGKLQF         TRAV6*01  TRAJ24*01
# 92767       30593  TRA    CAPQGATNKLIF      TRAV12-2*01  TRAJ32*01
# 92769       30594  TRA  CLVGGSGGYNKLIF         TRAV4*01   TRAJ4*01
#
#            species antigen.epitope antigen.gene antigen.species  vdjdb.score
# 0      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# 3      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# 7      HomoSapiens        FLKEKGGL          Nef           HIV-1            2
# 9      HomoSapiens        FLKEQGGL          Nef           HIV-1            2
# 12     HomoSapiens        FLKEQGGL          Nef           HIV-1            2
# ...            ...             ...          ...             ...          ...
# 92761  HomoSapiens    PQPELPYPQPQL       Gluten           Wheat            0
# 92763  HomoSapiens    PQPELPYPQPQL       Gluten           Wheat            0
# 92765  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            0
# 92767  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            2
# 92769  HomoSapiens   PQQPFPQPEQPFP       Gluten           Wheat            0
#
# [34722 rows x 10 columns]

# %%
data_alpha['antigen.epitope'].value_counts()
# Out:
# KLGGALQAK     13701
# GILGFVFTL      4700
# NLVPMVATV      2681
# AVFDRKSDAK     1730
# RAKFKQLL       1227
#               ...
# FSAVGDICY         1
# ALSGVFCGV         1
# TLATHGLAAV        1
# FLGRYMSAL         1
# IQPGQTFSV         1
# Name: antigen.epitope, Length: 898, dtype: int64

# %%
data_beta['antigen.epitope'].value_counts()
# Out:
# KLGGALQAK      13968
# GILGFVFTL       5248
# NLVPMVATV       5235
# ELAGIGILTV      2282
# AVFDRKSDAK      1782
#                ...
# IIWFLLLSV          1
# ALSGVFCGV          1
# GPQQSFPEQEA        1
# FLGRYMSAL          1
# FMSEAKCWT          1
# Name: antigen.epitope, Length: 1088, dtype: int64

# %%
data_alpha = data_alpha[(data_alpha['antigen.epitope'] == 'KLGGALQAK') | (data_alpha['antigen.epitope'] == 'GILGFVFTL')| (data_alpha['antigen.epitope'] == 'NLVPMVATV')| (data_alpha['antigen.epitope'] == 'AVFDRKSDAK')| (data_alpha['antigen.epitope'] == 'RAKFKQLL')].copy()

# %%
data_alpha
# Out:
#        complex.id gene          cdr3_a_aa         v_a_gene   j_a_gene  \
# 1287          114  TRA       CAGAGSQGNLIF        TRAV27*01  TRAJ42*01
# 1331          136  TRA       CAGAGSQGNLIF        TRAV27*01  TRAJ42*01
# 1333          137  TRA       CAGAGSQGNLIF        TRAV27*01  TRAJ42*01
# 1335          138  TRA       CAGAGSQGNLIF        TRAV27*01  TRAJ42*01
# 1351          146  TRA        CARNTGNQFYF        TRAV24*01  TRAJ49*01
# ...           ...  ...                ...              ...        ...
# 85101       27977  TRA  CAFMINAGGTSYGKLTF      TRAV38-1*01  TRAJ52*01
# 85103       27978  TRA      CAVFSGSARQLTF      TRAV12-2*01  TRAJ22*01
# 85105       27979  TRA  CAYSPSAGGTSYGKLTF  TRAV38-2/DV8*01  TRAJ52*01
# 85107       27980  TRA   CASPDVTTDSWGKFQF        TRAV24*01  TRAJ24*01
# 85109       27981  TRA     CAVGNGGSQGNLIF       TRAV1-2*01  TRAJ42*01
#
#            species antigen.epitope antigen.gene antigen.species  vdjdb.score
# 1287   HomoSapiens       GILGFVFTL            M      InfluenzaA            3
# 1331   HomoSapiens       GILGFVFTL            M      InfluenzaA            3
# 1333   HomoSapiens       GILGFVFTL            M      InfluenzaA            3
# 1335   HomoSapiens       GILGFVFTL            M      InfluenzaA            3
# 1351   HomoSapiens       NLVPMVATV         pp65             CMV            3
# ...            ...             ...          ...             ...          ...
# 85101  HomoSapiens       GILGFVFTL            M      InfluenzaA            0
# 85103  HomoSapiens       GILGFVFTL            M      InfluenzaA            0
# 85105  HomoSapiens       GILGFVFTL            M      InfluenzaA            0
# 85107  HomoSapiens       GILGFVFTL            M      InfluenzaA            0
# 85109  HomoSapiens       GILGFVFTL            M      InfluenzaA            0
#
# [24039 rows x 10 columns]

# %%
data_alpha.to_csv('alpha_p.csv')

# %%
data_alpha['antigen.epitope'].value_counts()
# Out:
# KLGGALQAK     13701
# GILGFVFTL      4700
# NLVPMVATV      2681
# AVFDRKSDAK     1730
# RAKFKQLL       1227
# Name: antigen.epitope, dtype: int64

# %%
import numpy as np

#创造‘TCRrep’类
#alpha chain
data_alpha = pd.read_csv("alpha_p.csv")
tr_alpha = TCRrep(cell_df=data_alpha, 
                  organism='human', 
                  chains=['alpha'], 
                  db_file='alphabeta_gammadelta_db.tsv')
tr_alpha.compute_distances()

alpha_distance_matrix = tr_alpha.pw_alpha
np.save('alpha_distance_people_matrix.npy', alpha_distance_matrix)
tr_alpha.pw_alpha
# Out:
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\tcrdist\repertoire.py:159: UserWarning: cell_df needs a counts column to track clonal number of frequency
#
#   self._validate_cell_df()
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\tcrdist\repertoire.py:791: UserWarning: No 'count' column provided; count column set to 1
#   warnings.warn("No 'count' column provided; count column set to 1")
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\tcrdist\repertoire.py:201: UserWarning:
#
# When TCRrep.<clone_df> size 24039 > 10,000.
# 	TCRrep.compute_distances() may be called explicitly by a user
# 	with knowledge of system memory availability.
# 	However, it's HIGHLY unlikely that you want to compute such
# 	a large numpy array. INSTEAD, if you want all pairwise distance,
# 	you will likely want to set an appropriate number of cpus with TCRrep.cpus = x,
# 	and then generate a scipy.sparse csr matrix of distances with:
# 	TCRrep.compute_sparse_rect_distances(radius=50, chunk_size=100), leaving df and df2 arguments blank.
# 	When you do this the results will be stored as TCRrep.rw_beta instead of TCRrep.pw_beta.
# 	This function is highly useful for comparing a smaller number of sequences against a bulk set
# 	In such a case, you can specify df and df2 arguments to create a non-square matrix of distances.
# 	See https://tcrdist3.readthedocs.io/en/latest/sparsity.html?highlight=sparse for more info.
#
#   warnings.warn(f"\n\nWhen TCRrep.<clone_df> size {self.clone_df.shape[0]} > 10,000.\n"
# array([[  0,   0,   0, ..., 166, 168, 106],
#        [  0,   0,   0, ..., 166, 168, 106],
#        [  0,   0,   0, ..., 166, 168, 106],
#        ...,
#        [166, 166, 166, ...,   0, 169, 157],
#        [168, 168, 168, ..., 169,   0, 154],
#        [106, 106, 106, ..., 157, 154,   0]], dtype=int16)

# %%
#beta chain
from tcrdist.repertoire import TCRrep
import numpy as np
data_beta = pd.read_csv("beta.csv")
tr_beta = TCRrep(cell_df=data_beta, 
                 organism='mouse', 
                 chains=['beta'], 
                 db_file='alphabeta_gammadelta_db.tsv',
                 deduplicate=True)
tr_beta.compute_distances()
beta_distance_matrix = tr_beta.pw_beta
np.save('beta_distance_people_matrix.npy', beta_distance_matrix)
tr_beta.pw_beta

# %%
# 通过complex.id进行合并，假设每个complex.id对应一对alpha和beta链
# 确保complex.id不等于0
#data_alpha = data_alpha[data_alpha['complex.id'] != 0]
#data_beta = data_beta[data_beta['complex.id'] != 0]
# 合并alpha和beta链数据（拼接）
#data_combined = pd.merge(data_alpha, data_beta, on='complex.id', suffixes=('_alpha', '_beta'))
#data_combined['combined_feature'] = data_combined['cdr3_a_aa'] + "_" + data_combined['cdr3_b_aa']

#data_combined.to_csv('data_combined.csv')
#data_combined

# %%
#data_combined['cdr3_b_aa'] = data_combined['combined_feature']
#tr = TCRrep(cell_df = data_combined,
           # organism = 'mouse', 
            #chains = ['beta'],  # 这里chains参数是必须的，但因为我们用的是综合特征，所以实际选择哪个链并不重要
           # db_file='alphabeta_gammadelta_db.tsv', 
          #  )
#tr.compute_distances()
#tr.pw_beta
